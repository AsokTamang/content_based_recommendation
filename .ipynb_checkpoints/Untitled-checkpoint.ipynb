# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from utils import *
import tabulate
import csv

# %% [markdown]
# **Reading the datas**

# %%
item_train = pd.read_csv('data/content_item_train.csv',header=None)
user_train = pd.read_csv('data/content_user_train.csv',header=None)
y_train    = pd.read_csv('data/content_y_train.csv',header=None)  #the rating value of the movies rated by the user
item_headers = pd.read_csv('data/content_item_train_header.txt')
user_headers = pd.read_csv('data/content_user_train_header.txt')
item_vecs = pd.read_csv('data/content_item_vecs.csv',header=None)
movie_list = pd.read_csv('data/content_movie_list.csv')
print(user_headers)
print(item_headers)
user_index = 3  #we start with index 3 for user dataset while training and evaluating the model, skipping the user id, rating count and average rating of user
item_index = 1  #we start with index 1 for item dataset while training and evaluating the model, skipping the movie id
# Out:
# Empty DataFrame
# Columns: [user id, rating count, rating ave, Action, Adventure, Animation, Children, Comedy, Crime, Documentary, Drama, Fantasy, Horror, Mystery, Romance, Sci-Fi, Thriller]
# Index: []
# Empty DataFrame
# Columns: [movie id, year, ave rating, Action, Adventure, Animation, Children, Comedy, Crime, Documentary, Drama, Fantasy, Horror, Mystery, Romance, Sci-Fi, Thriller]
# Index: []

# %% [markdown]
# **Features of users and items**

# %%
user_features = list(user_headers.columns)
item_features = list(item_headers.columns)
print(f'The features of item are: {item_features}')
print(f'The features of user are: {user_features}')
# Out:
# The features of item are: ['movie id', 'year', 'ave rating', 'Action', 'Adventure', 'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Horror', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller']
# The features of user are: ['user id', 'rating count', 'rating ave', 'Action', 'Adventure', 'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Horror', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller']

# %% [markdown]
# **making a dictionary of movie id as key and title and genre as the values**

# %%
movie_list_array = np.array(movie_list)
movie_dict = defaultdict(dict)
#here based on the movie id , we are storing the title of the movie and the genre
for row in movie_list_array:
    movie_dict[row[0]]['title'] = row[1] 
    movie_dict[row[0]]['genre'] = row[2]
movie_dict
# Out:
# defaultdict(dict,
#             {4054: {'title': 'Save the Last Dance (2001)',
#               'genre': 'Drama|Romance'},
#              4069: {'title': 'Wedding Planner, The (2001)',
#               'genre': 'Comedy|Romance'},
#              4148: {'title': 'Hannibal (2001)', 'genre': 'Horror|Thriller'},
#              4149: {'title': 'Saving Silverman (Evil Woman) (2001)',
#               'genre': 'Comedy|Romance'},
#              4153: {'title': 'Down to Earth (2001)',
#               'genre': 'Comedy|Fantasy|Romance'},
#              4161: {'title': 'Mexican, The (2001)', 'genre': 'Action|Comedy'},
#              4167: {'title': '15 Minutes (2001)', 'genre': 'Thriller'},
#              4223: {'title': 'Enemy at the Gates (2001)', 'genre': 'Drama'},
#              4228: {'title': 'Heartbreakers (2001)',
#               'genre': 'Comedy|Crime|Romance'},
#              4232: {'title': 'Spy Kids (2001)',
#               'genre': 'Action|Adventure|Children|Comedy'},
#              4238: {'title': 'Along Came a Spider (2001)',
#               'genre': 'Action|Crime|Mystery|Thriller'},
#              4239: {'title': 'Blow (2001)', 'genre': 'Crime|Drama'},
#              4246: {'title': "Bridget Jones's Diary (2001)",
#               'genre': 'Comedy|Drama|Romance'},
#              4247: {'title': 'Joe Dirt (2001)',
#               'genre': 'Adventure|Comedy|Mystery|Romance'},
#              4254: {'title': 'Crocodile Dundee in Los Angeles (2001)',
#               'genre': 'Comedy|Drama'},
#              4270: {'title': 'Mummy Returns, The (2001)',
#               'genre': 'Action|Adventure|Comedy|Thriller'},
#              4299: {'title': "Knight's Tale, A (2001)",
#               'genre': 'Action|Comedy|Romance'},
#              4306: {'title': 'Shrek (2001)',
#               'genre': 'Adventure|Animation|Children|Comedy|Fantasy|Romance'},
#              4308: {'title': 'Moulin Rouge (2001)', 'genre': 'Drama|Romance'},
#              4310: {'title': 'Pearl Harbor (2001)',
#               'genre': 'Action|Drama|Romance'},
#              4340: {'title': 'Animal, The (2001)', 'genre': 'Comedy'},
#              4343: {'title': 'Evolution (2001)', 'genre': 'Comedy|Sci-Fi'},
#              4344: {'title': 'Swordfish (2001)',
#               'genre': 'Action|Crime|Drama'},
#              4366: {'title': 'Atlantis: The Lost Empire (2001)',
#               'genre': 'Adventure|Animation|Children|Fantasy'},
#              4367: {'title': 'Lara Croft: Tomb Raider (2001)',
#               'genre': 'Action|Adventure'},
#              4368: {'title': 'Dr. Dolittle 2 (2001)', 'genre': 'Comedy'},
#              4369: {'title': 'Fast and the Furious, The (2001)',
#               'genre': 'Action|Crime|Thriller'},
#              4370: {'title': 'A.I. Artificial Intelligence (2001)',
#               'genre': 'Adventure|Drama|Sci-Fi'},
#              4386: {'title': 'Cats & Dogs (2001)', 'genre': 'Children|Comedy'},
#              4388: {'title': 'Scary Movie 2 (2001)', 'genre': 'Comedy'},
#              4446: {'title': 'Final Fantasy: The Spirits Within (2001)',
#               'genre': 'Adventure|Animation|Fantasy|Sci-Fi'},
#              4447: {'title': 'Legally Blonde (2001)',
#               'genre': 'Comedy|Romance'},
#              4448: {'title': 'Score, The (2001)', 'genre': 'Action|Drama'},
#              4638: {'title': 'Jurassic Park III (2001)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              4639: {'title': "America's Sweethearts (2001)",
#               'genre': 'Comedy|Romance'},
#              4641: {'title': 'Ghost World (2001)', 'genre': 'Comedy|Drama'},
#              4643: {'title': 'Planet of the Apes (2001)',
#               'genre': 'Action|Adventure|Drama|Sci-Fi'},
#              4700: {'title': 'Princess Diaries, The (2001)',
#               'genre': 'Children|Comedy|Romance'},
#              4701: {'title': 'Rush Hour 2 (2001)', 'genre': 'Action|Comedy'},
#              4718: {'title': 'American Pie 2 (2001)', 'genre': 'Comedy'},
#              4720: {'title': 'Others, The (2001)',
#               'genre': 'Drama|Horror|Mystery|Thriller'},
#              4728: {'title': 'Rat Race (2001)', 'genre': 'Comedy'},
#              4734: {'title': 'Jay and Silent Bob Strike Back (2001)',
#               'genre': 'Adventure|Comedy'},
#              4776: {'title': 'Training Day (2001)',
#               'genre': 'Crime|Drama|Thriller'},
#              4816: {'title': 'Zoolander (2001)', 'genre': 'Comedy'},
#              4823: {'title': 'Serendipity (2001)', 'genre': 'Comedy|Romance'},
#              4848: {'title': 'Mulholland Drive (2001)',
#               'genre': 'Crime|Drama|Mystery|Thriller'},
#              4865: {'title': 'From Hell (2001)',
#               'genre': 'Crime|Horror|Mystery|Thriller'},
#              4873: {'title': 'Waking Life (2001)',
#               'genre': 'Animation|Drama|Fantasy'},
#              4874: {'title': 'K-PAX (2001)',
#               'genre': 'Drama|Fantasy|Mystery|Sci-Fi'},
#              4876: {'title': 'Thirteen Ghosts (a.k.a. Thir13en Ghosts) (2001)',
#               'genre': 'Horror|Thriller'},
#              4878: {'title': 'Donnie Darko (2001)',
#               'genre': 'Drama|Mystery|Sci-Fi|Thriller'},
#              4881: {'title': "Man Who Wasn't There, The (2001)",
#               'genre': 'Crime|Drama'},
#              4886: {'title': 'Monsters, Inc. (2001)',
#               'genre': 'Adventure|Animation|Children|Comedy|Fantasy'},
#              4887: {'title': 'One, The (2001)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              4890: {'title': 'Shallow Hal (2001)',
#               'genre': 'Comedy|Fantasy|Romance'},
#              4896: {'title': "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)",
#               'genre': 'Adventure|Children|Fantasy'},
#              4901: {'title': 'Spy Game (2001)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              4902: {'title': "Devil's Backbone, The (Espinazo del diablo, El) (2001)",
#               'genre': 'Drama|Fantasy|Horror|Thriller'},
#              4903: {'title': 'In the Bedroom (2001)', 'genre': 'Drama'},
#              4958: {'title': 'Behind Enemy Lines (2001)',
#               'genre': 'Action|Drama'},
#              4963: {'title': "Ocean's Eleven (2001)",
#               'genre': 'Crime|Thriller'},
#              4967: {'title': "No Man's Land (2001)", 'genre': 'Drama'},
#              4973: {'title': "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)",
#               'genre': 'Comedy|Romance'},
#              4974: {'title': 'Not Another Teen Movie (2001)',
#               'genre': 'Comedy'},
#              4975: {'title': 'Vanilla Sky (2001)',
#               'genre': 'Mystery|Romance|Sci-Fi|Thriller'},
#              4979: {'title': 'Royal Tenenbaums, The (2001)',
#               'genre': 'Comedy|Drama'},
#              4992: {'title': 'Kate & Leopold (2001)',
#               'genre': 'Comedy|Romance'},
#              4993: {'title': 'Lord of the Rings: The Fellowship of the Ring, The (2001)',
#               'genre': 'Adventure|Fantasy'},
#              4994: {'title': 'Majestic, The (2001)',
#               'genre': 'Comedy|Drama|Romance'},
#              4995: {'title': 'Beautiful Mind, A (2001)',
#               'genre': 'Drama|Romance'},
#              5010: {'title': 'Black Hawk Down (2001)',
#               'genre': 'Action|Drama'},
#              5013: {'title': 'Gosford Park (2001)',
#               'genre': 'Comedy|Drama|Mystery'},
#              5014: {'title': 'I Am Sam (2001)', 'genre': 'Drama'},
#              5015: {'title': "Monster's Ball (2001)",
#               'genre': 'Drama|Romance'},
#              5025: {'title': 'Orange County (2002)', 'genre': 'Comedy'},
#              5026: {'title': 'Brotherhood of the Wolf (Pacte des loups, Le) (2001)',
#               'genre': 'Action|Mystery|Thriller'},
#              5064: {'title': 'The Count of Monte Cristo (2002)',
#               'genre': 'Action|Adventure|Drama|Thriller'},
#              5065: {'title': 'Mothman Prophecies, The (2002)',
#               'genre': 'Drama|Fantasy|Horror|Mystery|Thriller'},
#              5066: {'title': 'Walk to Remember, A (2002)',
#               'genre': 'Drama|Romance'},
#              5072: {'title': 'Metropolis (2001)', 'genre': 'Animation|Sci-Fi'},
#              5108: {'title': 'John Q (2002)', 'genre': 'Crime|Drama|Thriller'},
#              5110: {'title': 'Super Troopers (2001)',
#               'genre': 'Comedy|Crime|Mystery'},
#              5128: {'title': 'Queen of the Damned (2002)',
#               'genre': 'Fantasy|Horror'},
#              5135: {'title': 'Monsoon Wedding (2001)',
#               'genre': 'Comedy|Romance'},
#              5152: {'title': 'We Were Soldiers (2002)',
#               'genre': 'Action|Drama'},
#              5171: {'title': 'Time Machine, The (2002)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              5218: {'title': 'Ice Age (2002)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              5219: {'title': 'Resident Evil (2002)',
#               'genre': 'Action|Horror|Sci-Fi|Thriller'},
#              5220: {'title': 'Showtime (2002)', 'genre': 'Action|Comedy'},
#              5254: {'title': 'Blade II (2002)',
#               'genre': 'Action|Horror|Thriller'},
#              5265: {'title': 'Death to Smoochy (2002)',
#               'genre': 'Comedy|Crime|Drama'},
#              5266: {'title': 'Panic Room (2002)', 'genre': 'Thriller'},
#              5267: {'title': 'Rookie, The (2002)', 'genre': 'Drama'},
#              5283: {'title': "National Lampoon's Van Wilder (2002)",
#               'genre': 'Comedy'},
#              5294: {'title': 'Frailty (2001)',
#               'genre': 'Crime|Drama|Thriller'},
#              5296: {'title': 'Sweetest Thing, The (2002)',
#               'genre': 'Comedy|Romance'},
#              5299: {'title': 'My Big Fat Greek Wedding (2002)',
#               'genre': 'Comedy|Romance'},
#              5313: {'title': 'The Scorpion King (2002)',
#               'genre': 'Action|Adventure|Fantasy|Thriller'},
#              5329: {'title': 'Salton Sea, The (2002)',
#               'genre': 'Crime|Drama|Thriller'},
#              5349: {'title': 'Spider-Man (2002)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              5377: {'title': 'About a Boy (2002)',
#               'genre': 'Comedy|Drama|Romance'},
#              5378: {'title': 'Star Wars: Episode II - Attack of the Clones (2002)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              5380: {'title': 'Importance of Being Earnest, The (2002)',
#               'genre': 'Comedy|Drama|Romance'},
#              5388: {'title': 'Insomnia (2002)',
#               'genre': 'Action|Crime|Drama|Mystery|Thriller'},
#              5400: {'title': 'Sum of All Fears, The (2002)',
#               'genre': 'Drama|Thriller'},
#              5418: {'title': 'Bourne Identity, The (2002)',
#               'genre': 'Action|Mystery|Thriller'},
#              5419: {'title': 'Scooby-Doo (2002)',
#               'genre': 'Adventure|Children|Comedy|Fantasy|Mystery'},
#              5444: {'title': 'Lilo & Stitch (2002)',
#               'genre': 'Adventure|Animation|Children|Sci-Fi'},
#              5445: {'title': 'Minority Report (2002)',
#               'genre': 'Action|Crime|Mystery|Sci-Fi|Thriller'},
#              5449: {'title': 'Mr. Deeds (2002)', 'genre': 'Comedy|Romance'},
#              5459: {'title': 'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)',
#               'genre': 'Action|Comedy|Sci-Fi'},
#              5463: {'title': 'Reign of Fire (2002)',
#               'genre': 'Action|Adventure|Fantasy'},
#              5464: {'title': 'Road to Perdition (2002)',
#               'genre': 'Crime|Drama'},
#              5481: {'title': 'Austin Powers in Goldmember (2002)',
#               'genre': 'Comedy'},
#              5502: {'title': 'Signs (2002)',
#               'genre': 'Horror|Sci-Fi|Thriller'},
#              5505: {'title': 'Good Girl, The (2002)', 'genre': 'Comedy|Drama'},
#              5507: {'title': 'xXx (2002)', 'genre': 'Action|Crime|Thriller'},
#              5528: {'title': 'One Hour Photo (2002)',
#               'genre': 'Drama|Thriller'},
#              5574: {'title': 'Transporter, The (2002)',
#               'genre': 'Action|Crime'},
#              5577: {'title': 'Igby Goes Down (2002)', 'genre': 'Comedy|Drama'},
#              5608: {'title': 'Das Experiment (Experiment, The) (2001)',
#               'genre': 'Drama|Thriller'},
#              5618: {'title': 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)',
#               'genre': 'Adventure|Animation|Fantasy'},
#              5620: {'title': 'Sweet Home Alabama (2002)',
#               'genre': 'Comedy|Romance'},
#              5621: {'title': 'Tuxedo, The (2002)', 'genre': 'Action|Comedy'},
#              5630: {'title': 'Red Dragon (2002)',
#               'genre': 'Crime|Mystery|Thriller'},
#              5669: {'title': 'Bowling for Columbine (2002)',
#               'genre': 'Documentary'},
#              5673: {'title': 'Punch-Drunk Love (2002)',
#               'genre': 'Comedy|Drama|Romance'},
#              5679: {'title': 'Ring, The (2002)',
#               'genre': 'Horror|Mystery|Thriller'},
#              5785: {'title': 'Jackass: The Movie (2002)',
#               'genre': 'Action|Comedy|Documentary'},
#              5791: {'title': 'Frida (2002)', 'genre': 'Drama|Romance'},
#              5810: {'title': '8 Mile (2002)', 'genre': 'Drama'},
#              5812: {'title': 'Far from Heaven (2002)',
#               'genre': 'Drama|Romance'},
#              5816: {'title': 'Harry Potter and the Chamber of Secrets (2002)',
#               'genre': 'Adventure|Fantasy'},
#              5872: {'title': 'Die Another Day (2002)',
#               'genre': 'Action|Adventure|Thriller'},
#              5878: {'title': 'Talk to Her (Hable con Ella) (2002)',
#               'genre': 'Drama|Romance'},
#              5881: {'title': 'Solaris (2002)',
#               'genre': 'Drama|Romance|Sci-Fi'},
#              5902: {'title': 'Adaptation (2002)',
#               'genre': 'Comedy|Drama|Romance'},
#              5903: {'title': 'Equilibrium (2002)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              5943: {'title': 'Maid in Manhattan (2002)',
#               'genre': 'Comedy|Romance'},
#              5944: {'title': 'Star Trek: Nemesis (2002)',
#               'genre': 'Action|Drama|Sci-Fi|Thriller'},
#              5945: {'title': 'About Schmidt (2002)', 'genre': 'Comedy|Drama'},
#              5952: {'title': 'Lord of the Rings: The Two Towers, The (2002)',
#               'genre': 'Adventure|Fantasy'},
#              5954: {'title': '25th Hour (2002)', 'genre': 'Crime|Drama'},
#              5956: {'title': 'Gangs of New York (2002)',
#               'genre': 'Crime|Drama'},
#              5957: {'title': 'Two Weeks Notice (2002)',
#               'genre': 'Comedy|Romance'},
#              5989: {'title': 'Catch Me If You Can (2002)',
#               'genre': 'Crime|Drama'},
#              5991: {'title': 'Chicago (2002)', 'genre': 'Comedy|Crime|Drama'},
#              5992: {'title': 'Hours, The (2002)', 'genre': 'Drama|Romance'},
#              5995: {'title': 'Pianist, The (2002)', 'genre': 'Drama'},
#              6003: {'title': 'Confessions of a Dangerous Mind (2002)',
#               'genre': 'Comedy|Crime|Drama|Thriller'},
#              6016: {'title': 'City of God (Cidade de Deus) (2002)',
#               'genre': 'Action|Adventure|Crime|Drama|Thriller'},
#              6058: {'title': 'Final Destination 2 (2003)',
#               'genre': 'Horror|Thriller'},
#              6059: {'title': 'Recruit, The (2003)',
#               'genre': 'Action|Thriller'},
#              6155: {'title': 'How to Lose a Guy in 10 Days (2003)',
#               'genre': 'Comedy|Romance'},
#              6156: {'title': 'Shanghai Knights (2003)',
#               'genre': 'Action|Adventure|Comedy'},
#              6157: {'title': 'Daredevil (2003)', 'genre': 'Action|Crime'},
#              6188: {'title': 'Old School (2003)', 'genre': 'Comedy'},
#              6218: {'title': 'Bend It Like Beckham (2002)',
#               'genre': 'Comedy|Drama|Romance'},
#              6281: {'title': 'Phone Booth (2002)', 'genre': 'Drama|Thriller'},
#              6283: {'title': 'Cowboy Bebop: The Movie (Cowboy Bebop: Tengoku no Tobira) (2001)',
#               'genre': 'Action|Animation|Sci-Fi|Thriller'},
#              6287: {'title': 'Anger Management (2003)', 'genre': 'Comedy'},
#              6294: {'title': 'Bulletproof Monk (2003)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              6296: {'title': 'Mighty Wind, A (2003)', 'genre': 'Comedy'},
#              6297: {'title': 'Holes (2003)',
#               'genre': 'Adventure|Children|Comedy|Mystery'},
#              6323: {'title': 'Identity (2003)',
#               'genre': 'Crime|Horror|Mystery|Thriller'},
#              6331: {'title': 'Spellbound (2002)', 'genre': 'Documentary'},
#              6333: {'title': 'X2: X-Men United (2003)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              6365: {'title': 'Matrix Reloaded, The (2003)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              6367: {'title': 'Down with Love (2003)',
#               'genre': 'Comedy|Romance'},
#              6373: {'title': 'Bruce Almighty (2003)',
#               'genre': 'Comedy|Drama|Fantasy|Romance'},
#              6377: {'title': 'Finding Nemo (2003)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              6378: {'title': 'Italian Job, The (2003)',
#               'genre': 'Action|Crime'},
#              6383: {'title': '2 Fast 2 Furious (Fast and the Furious 2, The) (2003)',
#               'genre': 'Action|Crime|Thriller'},
#              6385: {'title': 'Whale Rider (2002)', 'genre': 'Drama'},
#              6482: {'title': 'Dumb and Dumberer: When Harry Met Lloyd (2003)',
#               'genre': 'Comedy'},
#              6502: {'title': '28 Days Later (2002)',
#               'genre': 'Action|Horror|Sci-Fi'},
#              6503: {'title': "Charlie's Angels: Full Throttle (2003)",
#               'genre': 'Action|Adventure|Comedy|Crime|Thriller'},
#              6534: {'title': 'Hulk (2003)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              6535: {'title': 'Legally Blonde 2: Red, White & Blonde (2003)',
#               'genre': 'Comedy'},
#              6537: {'title': 'Terminator 3: Rise of the Machines (2003)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              6539: {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl (2003)',
#               'genre': 'Action|Adventure|Comedy|Fantasy'},
#              6541: {'title': 'League of Extraordinary Gentlemen, The (a.k.a. LXG) (2003)',
#               'genre': 'Action|Fantasy|Sci-Fi'},
#              6548: {'title': 'Bad Boys II (2003)',
#               'genre': 'Action|Comedy|Crime|Thriller'},
#              6550: {'title': 'Johnny English (2003)',
#               'genre': 'Action|Comedy|Thriller'},
#              6552: {'title': 'Dirty Pretty Things (2002)',
#               'genre': 'Crime|Drama|Thriller'},
#              6564: {'title': 'Lara Croft Tomb Raider: The Cradle of Life (2003)',
#               'genre': 'Action|Adventure|Comedy|Romance|Thriller'},
#              6565: {'title': 'Seabiscuit (2003)', 'genre': 'Drama'},
#              6586: {'title': 'American Wedding (American Pie 3) (2003)',
#               'genre': 'Comedy'},
#              6593: {'title': 'Freaky Friday (2003)',
#               'genre': 'Children|Comedy|Fantasy'},
#              6595: {'title': 'S.W.A.T. (2003)', 'genre': 'Action|Thriller'},
#              6618: {'title': 'Shaolin Soccer (Siu lam juk kau) (2001)',
#               'genre': 'Action|Comedy'},
#              6620: {'title': 'American Splendor (2003)',
#               'genre': 'Comedy|Drama'},
#              6708: {'title': 'Matchstick Men (2003)',
#               'genre': 'Comedy|Crime|Drama'},
#              6709: {'title': 'Once Upon a Time in Mexico (2003)',
#               'genre': 'Action|Adventure|Crime|Thriller'},
#              6711: {'title': 'Lost in Translation (2003)',
#               'genre': 'Comedy|Drama|Romance'},
#              6753: {'title': 'Secondhand Lions (2003)',
#               'genre': 'Children|Comedy|Drama'},
#              6754: {'title': 'Underworld (2003)',
#               'genre': 'Action|Fantasy|Horror'},
#              6755: {'title': 'Bubba Ho-tep (2002)', 'genre': 'Comedy|Horror'},
#              6764: {'title': 'Rundown, The (2003)',
#               'genre': 'Action|Adventure|Comedy'},
#              6773: {'title': 'Triplets of Belleville, The (Les triplettes de Belleville) (2003)',
#               'genre': 'Animation|Comedy|Fantasy'},
#              6863: {'title': 'School of Rock (2003)', 'genre': 'Comedy'},
#              6867: {'title': 'Station Agent, The (2003)',
#               'genre': 'Comedy|Drama'},
#              6870: {'title': 'Mystic River (2003)',
#               'genre': 'Crime|Drama|Mystery'},
#              6873: {'title': 'Intolerable Cruelty (2003)',
#               'genre': 'Comedy|Romance'},
#              6874: {'title': 'Kill Bill: Vol. 1 (2003)',
#               'genre': 'Action|Crime|Thriller'},
#              6879: {'title': 'Runaway Jury (2003)', 'genre': 'Drama|Thriller'},
#              6888: {'title': 'Scary Movie 3 (2003)', 'genre': 'Comedy|Horror'},
#              6934: {'title': 'Matrix Revolutions, The (2003)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              6936: {'title': 'Elf (2003)', 'genre': 'Children|Comedy|Fantasy'},
#              6942: {'title': 'Love Actually (2003)',
#               'genre': 'Comedy|Drama|Romance'},
#              6947: {'title': 'Master and Commander: The Far Side of the World (2003)',
#               'genre': 'Adventure|Drama'},
#              6953: {'title': '21 Grams (2003)',
#               'genre': 'Crime|Drama|Mystery|Romance|Thriller'},
#              6957: {'title': 'Bad Santa (2003)', 'genre': 'Comedy|Crime'},
#              6958: {'title': 'Haunted Mansion, The (2003)',
#               'genre': 'Children|Comedy|Fantasy|Horror'},
#              7090: {'title': 'Hero (Ying xiong) (2002)',
#               'genre': 'Action|Adventure|Drama'},
#              7137: {'title': 'Cooler, The (2003)',
#               'genre': 'Comedy|Drama|Romance'},
#              7143: {'title': 'Last Samurai, The (2003)',
#               'genre': 'Action|Adventure|Drama'},
#              7147: {'title': 'Big Fish (2003)',
#               'genre': 'Drama|Fantasy|Romance'},
#              7149: {'title': "Something's Gotta Give (2003)",
#               'genre': 'Comedy|Drama|Romance'},
#              7150: {'title': 'Stuck on You (2003)', 'genre': 'Comedy'},
#              7151: {'title': 'Girl with a Pearl Earring (2003)',
#               'genre': 'Drama|Romance'},
#              7153: {'title': 'Lord of the Rings: The Return of the King, The (2003)',
#               'genre': 'Action|Adventure|Drama|Fantasy'},
#              7154: {'title': 'Mona Lisa Smile (2003)',
#               'genre': 'Drama|Romance'},
#              7156: {'title': 'Fog of War: Eleven Lessons from the Life of Robert S. McNamara, The (2003)',
#               'genre': 'Documentary'},
#              7160: {'title': 'Monster (2003)', 'genre': 'Crime|Drama'},
#              7162: {'title': 'Cold Mountain (2003)', 'genre': 'Drama|Romance'},
#              7163: {'title': 'Paycheck (2003)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              7173: {'title': 'Along Came Polly (2004)',
#               'genre': 'Comedy|Romance'},
#              7254: {'title': 'The Butterfly Effect (2004)',
#               'genre': 'Drama|Sci-Fi|Thriller'},
#              7263: {'title': 'Miracle (2004)', 'genre': 'Drama'},
#              7265: {'title': 'Dreamers, The (2003)', 'genre': 'Drama'},
#              7293: {'title': '50 First Dates (2004)',
#               'genre': 'Comedy|Romance'},
#              7317: {'title': 'EuroTrip (2004)', 'genre': 'Adventure|Comedy'},
#              7323: {'title': 'Good bye, Lenin! (2003)',
#               'genre': 'Comedy|Drama'},
#              7324: {'title': 'Hidalgo (2004)', 'genre': 'Adventure|Drama'},
#              7325: {'title': 'Starsky & Hutch (2004)',
#               'genre': 'Action|Comedy|Crime|Thriller'},
#              7347: {'title': 'Secret Window (2004)',
#               'genre': 'Mystery|Thriller'},
#              7360: {'title': 'Dawn of the Dead (2004)',
#               'genre': 'Action|Drama|Horror|Thriller'},
#              7361: {'title': 'Eternal Sunshine of the Spotless Mind (2004)',
#               'genre': 'Drama|Romance|Sci-Fi'},
#              7367: {'title': 'Ladykillers, The (2004)',
#               'genre': 'Comedy|Crime'},
#              7371: {'title': 'Dogville (2003)',
#               'genre': 'Drama|Mystery|Thriller'},
#              7373: {'title': 'Hellboy (2004)',
#               'genre': 'Action|Adventure|Fantasy|Horror'},
#              7438: {'title': 'Kill Bill: Vol. 2 (2004)',
#               'genre': 'Action|Drama|Thriller'},
#              7439: {'title': 'Punisher, The (2004)',
#               'genre': 'Action|Crime|Thriller'},
#              7444: {'title': '13 Going on 30 (2004)',
#               'genre': 'Comedy|Fantasy|Romance'},
#              7445: {'title': 'Man on Fire (2004)',
#               'genre': 'Action|Crime|Drama|Mystery|Thriller'},
#              7451: {'title': 'Mean Girls (2004)', 'genre': 'Comedy'},
#              7454: {'title': 'Van Helsing (2004)',
#               'genre': 'Action|Adventure|Fantasy|Horror'},
#              7458: {'title': 'Troy (2004)', 'genre': 'Action|Adventure|Drama'},
#              8014: {'title': 'Spring, Summer, Fall, Winter... and Spring (Bom yeoreum gaeul gyeoul geurigo bom) (2003)',
#               'genre': 'Drama'},
#              8360: {'title': 'Shrek 2 (2004)',
#               'genre': 'Adventure|Animation|Children|Comedy|Romance'},
#              8361: {'title': 'Day After Tomorrow, The (2004)',
#               'genre': 'Action|Adventure|Drama|Sci-Fi|Thriller'},
#              8366: {'title': 'Saved! (2004)', 'genre': 'Comedy|Drama'},
#              8368: {'title': 'Harry Potter and the Prisoner of Azkaban (2004)',
#               'genre': 'Adventure|Fantasy'},
#              8370: {'title': 'Blind Swordsman: Zatoichi, The (Zatôichi) (2003)',
#               'genre': 'Action|Comedy|Crime|Drama'},
#              8371: {'title': 'Chronicles of Riddick, The (2004)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              8373: {'title': 'Stepford Wives, The (2004)',
#               'genre': 'Comedy|Fantasy|Thriller'},
#              8376: {'title': 'Napoleon Dynamite (2004)', 'genre': 'Comedy'},
#              8464: {'title': 'Super Size Me (2004)',
#               'genre': 'Comedy|Documentary|Drama'},
#              8528: {'title': 'Dodgeball: A True Underdog Story (2004)',
#               'genre': 'Comedy'},
#              8529: {'title': 'Terminal, The (2004)',
#               'genre': 'Comedy|Drama|Romance'},
#              8533: {'title': 'Notebook, The (2004)', 'genre': 'Drama|Romance'},
#              8622: {'title': 'Fahrenheit 9/11 (2004)', 'genre': 'Documentary'},
#              8636: {'title': 'Spider-Man 2 (2004)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              8638: {'title': 'Before Sunset (2004)', 'genre': 'Drama|Romance'},
#              8640: {'title': 'King Arthur (2004)',
#               'genre': 'Action|Adventure|Drama'},
#              8641: {'title': 'Anchorman: The Legend of Ron Burgundy (2004)',
#               'genre': 'Comedy'},
#              8644: {'title': 'I, Robot (2004)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              8665: {'title': 'Bourne Supremacy, The (2004)',
#               'genre': 'Action|Crime|Thriller'},
#              8781: {'title': 'Manchurian Candidate, The (2004)',
#               'genre': 'Thriller'},
#              8783: {'title': 'Village, The (2004)',
#               'genre': 'Drama|Mystery|Thriller'},
#              8784: {'title': 'Garden State (2004)',
#               'genre': 'Comedy|Drama|Romance'},
#              8798: {'title': 'Collateral (2004)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              8807: {'title': 'Harold and Kumar Go to White Castle (2004)',
#               'genre': 'Adventure|Comedy'},
#              8810: {'title': 'AVP: Alien vs. Predator (2004)',
#               'genre': 'Action|Horror|Sci-Fi|Thriller'},
#              8861: {'title': 'Resident Evil: Apocalypse (2004)',
#               'genre': 'Action|Horror|Sci-Fi|Thriller'},
#              8865: {'title': 'Sky Captain and the World of Tomorrow (2004)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              8873: {'title': 'Motorcycle Diaries, The (Diarios de motocicleta) (2004)',
#               'genre': 'Adventure|Drama'},
#              8874: {'title': 'Shaun of the Dead (2004)',
#               'genre': 'Comedy|Horror'},
#              8907: {'title': 'Shark Tale (2004)',
#               'genre': 'Animation|Children|Comedy'},
#              8910: {'title': 'I Heart Huckabees (2004)', 'genre': 'Comedy'},
#              8914: {'title': 'Primer (2004)', 'genre': 'Drama|Sci-Fi'},
#              8917: {'title': 'Team America: World Police (2004)',
#               'genre': 'Action|Adventure|Animation|Comedy'},
#              8947: {'title': 'Grudge, The (2004)',
#               'genre': 'Horror|Mystery|Thriller'},
#              8949: {'title': 'Sideways (2004)',
#               'genre': 'Comedy|Drama|Romance'},
#              8950: {'title': 'The Machinist (2004)',
#               'genre': 'Drama|Mystery|Thriller'},
#              8957: {'title': 'Saw (2004)', 'genre': 'Horror|Mystery|Thriller'},
#              8958: {'title': 'Ray (2004)', 'genre': 'Drama'},
#              8961: {'title': 'Incredibles, The (2004)',
#               'genre': 'Action|Adventure|Animation|Children|Comedy'},
#              8965: {'title': 'Polar Express, The (2004)',
#               'genre': 'Adventure|Animation|Children|Fantasy'},
#              8969: {'title': 'Bridget Jones: The Edge of Reason (2004)',
#               'genre': 'Comedy|Drama|Romance'},
#              8970: {'title': 'Finding Neverland (2004)', 'genre': 'Drama'},
#              8972: {'title': 'National Treasure (2004)',
#               'genre': 'Action|Adventure|Drama|Mystery|Thriller'},
#              8977: {'title': 'Alexander (2004)',
#               'genre': 'Action|Adventure|Drama'},
#              8981: {'title': 'Closer (2004)', 'genre': 'Drama|Romance'},
#              8983: {'title': 'House of Flying Daggers (Shi mian mai fu) (2004)',
#               'genre': 'Action|Drama|Romance'},
#              8984: {'title': "Ocean's Twelve (2004)",
#               'genre': 'Action|Comedy|Crime|Thriller'},
#              8985: {'title': 'Blade: Trinity (2004)',
#               'genre': 'Action|Fantasy|Horror|Thriller'},
#              27611: {'title': 'Battlestar Galactica (2003)',
#               'genre': 'Drama|Sci-Fi'},
#              27660: {'title': 'Animatrix, The (2003)',
#               'genre': 'Action|Animation|Drama|Sci-Fi'},
#              27706: {'title': "Lemony Snicket's A Series of Unfortunate Events (2004)",
#               'genre': 'Adventure|Children|Comedy|Fantasy'},
#              27773: {'title': 'Old Boy (2003)', 'genre': 'Mystery|Thriller'},
#              27801: {'title': 'Ong-Bak: The Thai Warrior (Ong Bak) (2003)',
#               'genre': 'Action|Thriller'},
#              27808: {'title': 'Spanglish (2004)',
#               'genre': 'Comedy|Drama|Romance'},
#              27815: {'title': 'Chorus, The (Choristes, Les) (2004)',
#               'genre': 'Drama'},
#              27831: {'title': 'Layer Cake (2004)',
#               'genre': 'Crime|Drama|Thriller'},
#              27846: {'title': 'Corporation, The (2003)',
#               'genre': 'Documentary'},
#              27904: {'title': 'Scanner Darkly, A (2006)',
#               'genre': 'Animation|Drama|Mystery|Sci-Fi|Thriller'},
#              30707: {'title': 'Million Dollar Baby (2004)', 'genre': 'Drama'},
#              30749: {'title': 'Hotel Rwanda (2004)', 'genre': 'Drama'},
#              30793: {'title': 'Charlie and the Chocolate Factory (2005)',
#               'genre': 'Adventure|Children|Comedy|Fantasy'},
#              30810: {'title': 'Life Aquatic with Steve Zissou, The (2004)',
#               'genre': 'Adventure|Comedy|Fantasy'},
#              30812: {'title': 'Aviator, The (2004)', 'genre': 'Drama'},
#              30816: {'title': 'Phantom of the Opera, The (2004)',
#               'genre': 'Drama|Romance'},
#              30822: {'title': 'In Good Company (2004)',
#               'genre': 'Comedy|Drama'},
#              30825: {'title': 'Meet the Fockers (2004)', 'genre': 'Comedy'},
#              31221: {'title': 'Elektra (2005)',
#               'genre': 'Action|Adventure|Crime|Drama'},
#              31410: {'title': 'Downfall (Untergang, Der) (2004)',
#               'genre': 'Drama'},
#              31433: {'title': 'Wedding Date, The (2005)',
#               'genre': 'Comedy|Romance'},
#              31658: {'title': "Howl's Moving Castle (Hauru no ugoku shiro) (2004)",
#               'genre': 'Adventure|Animation|Fantasy|Romance'},
#              31685: {'title': 'Hitch (2005)', 'genre': 'Comedy|Romance'},
#              31696: {'title': 'Constantine (2005)',
#               'genre': 'Action|Fantasy|Horror|Thriller'},
#              31878: {'title': 'Kung Fu Hustle (Gong fu) (2004)',
#               'genre': 'Action|Comedy'},
#              32029: {'title': 'Hostage (2005)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              32031: {'title': 'Robots (2005)',
#               'genre': 'Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi'},
#              32587: {'title': 'Sin City (2005)',
#               'genre': 'Action|Crime|Mystery|Thriller'},
#              33004: {'title': "Hitchhiker's Guide to the Galaxy, The (2005)",
#               'genre': 'Adventure|Comedy|Sci-Fi'},
#              33162: {'title': 'Kingdom of Heaven (2005)',
#               'genre': 'Action|Drama|Romance'},
#              33166: {'title': 'Crash (2004)', 'genre': 'Crime|Drama'},
#              33493: {'title': 'Star Wars: Episode III - Revenge of the Sith (2005)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              33615: {'title': 'Madagascar (2005)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              33660: {'title': 'Cinderella Man (2005)',
#               'genre': 'Drama|Romance'},
#              33679: {'title': 'Mr. & Mrs. Smith (2005)',
#               'genre': 'Action|Adventure|Comedy|Romance'},
#              33794: {'title': 'Batman Begins (2005)', 'genre': 'Action|Crime'},
#              33836: {'title': 'Bewitched (2005)',
#               'genre': 'Comedy|Fantasy|Romance'},
#              34048: {'title': 'War of the Worlds (2005)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              34072: {'title': "March of the Penguins (Marche de l'empereur, La) (2005)",
#               'genre': 'Documentary'},
#              34150: {'title': 'Fantastic Four (2005)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              34162: {'title': 'Wedding Crashers (2005)',
#               'genre': 'Comedy|Romance'},
#              34319: {'title': 'Island, The (2005)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              34405: {'title': 'Serenity (2005)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              34437: {'title': 'Broken Flowers (2005)',
#               'genre': 'Comedy|Drama'},
#              34520: {'title': 'Dukes of Hazzard, The (2005)',
#               'genre': 'Action|Adventure|Comedy'},
#              35836: {'title': '40-Year-Old Virgin, The (2005)',
#               'genre': 'Comedy|Romance'},
#              36401: {'title': 'Brothers Grimm, The (2005)',
#               'genre': 'Comedy|Fantasy|Horror|Thriller'},
#              36517: {'title': 'Constant Gardener, The (2005)',
#               'genre': 'Drama|Thriller'},
#              36519: {'title': 'Transporter 2 (2005)',
#               'genre': 'Action|Crime|Thriller'},
#              36529: {'title': 'Lord of War (2005)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              36708: {'title': 'Family Guy Presents Stewie Griffin: The Untold Story (2005)',
#               'genre': 'Adventure|Animation|Comedy'},
#              37380: {'title': 'Doom (2005)', 'genre': 'Action|Horror|Sci-Fi'},
#              37384: {'title': 'Waiting... (2005)', 'genre': 'Comedy'},
#              37386: {'title': 'Aeon Flux (2005)', 'genre': 'Action|Sci-Fi'},
#              37727: {'title': 'Flightplan (2005)',
#               'genre': 'Action|Drama|Thriller'},
#              37729: {'title': 'Corpse Bride (2005)',
#               'genre': 'Animation|Comedy|Fantasy|Romance'},
#              37733: {'title': 'History of Violence, A (2005)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              37741: {'title': 'Capote (2005)', 'genre': 'Crime|Drama'},
#              37830: {'title': 'Final Fantasy VII: Advent Children (2004)',
#               'genre': 'Action|Adventure|Animation|Fantasy|Sci-Fi'},
#              38038: {'title': 'Wallace & Gromit in The Curse of the Were-Rabbit (2005)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              38061: {'title': 'Kiss Kiss Bang Bang (2005)',
#               'genre': 'Comedy|Crime|Mystery|Thriller'},
#              39183: {'title': 'Brokeback Mountain (2005)',
#               'genre': 'Drama|Romance'},
#              39292: {'title': 'Good Night, and Good Luck. (2005)',
#               'genre': 'Crime|Drama'},
#              39446: {'title': 'Saw II (2005)', 'genre': 'Horror|Thriller'},
#              40278: {'title': 'Jarhead (2005)', 'genre': 'Action|Drama'},
#              40583: {'title': 'Syriana (2005)', 'genre': 'Drama|Thriller'},
#              40629: {'title': 'Pride & Prejudice (2005)',
#               'genre': 'Drama|Romance'},
#              40732: {'title': 'Descent, The (2005)',
#               'genre': 'Adventure|Drama|Horror|Thriller'},
#              40815: {'title': 'Harry Potter and the Goblet of Fire (2005)',
#               'genre': 'Adventure|Fantasy|Thriller'},
#              40819: {'title': 'Walk the Line (2005)',
#               'genre': 'Drama|Romance'},
#              40826: {'title': 'Rent (2005)', 'genre': 'Drama|Romance'},
#              41285: {'title': 'Match Point (2005)',
#               'genre': 'Crime|Drama|Romance'},
#              41566: {'title': 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)',
#               'genre': 'Adventure|Children|Fantasy'},
#              41569: {'title': 'King Kong (2005)',
#               'genre': 'Action|Adventure|Drama|Fantasy|Thriller'},
#              41997: {'title': 'Munich (2005)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              42011: {'title': 'Fun with Dick and Jane (2005)',
#               'genre': 'Comedy|Crime'},
#              42723: {'title': 'Hostel (2005)', 'genre': 'Horror'},
#              42738: {'title': 'Underworld: Evolution (2006)',
#               'genre': 'Action|Fantasy|Horror'},
#              43928: {'title': 'Ultraviolet (2006)',
#               'genre': 'Action|Fantasy|Sci-Fi|Thriller'},
#              44022: {'title': 'Ice Age 2: The Meltdown (2006)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              44191: {'title': 'V for Vendetta (2006)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              44195: {'title': 'Thank You for Smoking (2006)',
#               'genre': 'Comedy|Drama'},
#              44199: {'title': 'Inside Man (2006)',
#               'genre': 'Crime|Drama|Thriller'},
#              44555: {'title': 'Lives of Others, The (Das leben der Anderen) (2006)',
#               'genre': 'Drama|Romance|Thriller'},
#              44665: {'title': 'Lucky Number Slevin (2006)',
#               'genre': 'Crime|Drama|Mystery'},
#              44761: {'title': 'Brick (2005)', 'genre': 'Crime|Drama|Mystery'},
#              44840: {'title': 'Benchwarmers, The (2006)', 'genre': 'Comedy'},
#              44972: {'title': 'Scary Movie 4 (2006)',
#               'genre': 'Comedy|Horror'},
#              44974: {'title': 'Hard Candy (2005)', 'genre': 'Drama|Thriller'},
#              45081: {'title': 'Silent Hill (2006)',
#               'genre': 'Fantasy|Horror|Thriller'},
#              45186: {'title': 'Mission: Impossible III (2006)',
#               'genre': 'Action|Adventure|Thriller'},
#              45431: {'title': 'Over the Hedge (2006)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              45447: {'title': 'Da Vinci Code, The (2006)',
#               'genre': 'Drama|Mystery|Thriller'},
#              45499: {'title': 'X-Men: The Last Stand (2006)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              45501: {'title': 'Break-Up, The (2006)',
#               'genre': 'Comedy|Drama|Romance'},
#              45517: {'title': 'Cars (2006)',
#               'genre': 'Animation|Children|Comedy'},
#              45666: {'title': 'Nacho Libre (2006)', 'genre': 'Comedy'},
#              45668: {'title': 'Lake House, The (2006)',
#               'genre': 'Drama|Fantasy|Romance'},
#              45672: {'title': 'Click (2006)',
#               'genre': 'Adventure|Comedy|Drama|Fantasy|Romance'},
#              45720: {'title': 'Devil Wears Prada, The (2006)',
#               'genre': 'Comedy|Drama'},
#              45722: {'title': "Pirates of the Caribbean: Dead Man's Chest (2006)",
#               'genre': 'Action|Adventure|Fantasy'},
#              45728: {'title': 'Clerks II (2006)', 'genre': 'Comedy'},
#              45880: {'title': 'Marie Antoinette (2006)',
#               'genre': 'Drama|Romance'},
#              45950: {'title': 'Inconvenient Truth, An (2006)',
#               'genre': 'Documentary'},
#              46335: {'title': 'Fast and the Furious: Tokyo Drift, The (Fast and the Furious 3, The) (2006)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              46530: {'title': 'Superman Returns (2006)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              46578: {'title': 'Little Miss Sunshine (2006)',
#               'genre': 'Adventure|Comedy|Drama'},
#              46723: {'title': 'Babel (2006)', 'genre': 'Drama|Thriller'},
#              46965: {'title': 'Snakes on a Plane (2006)',
#               'genre': 'Action|Comedy|Horror|Thriller'},
#              46970: {'title': 'Talladega Nights: The Ballad of Ricky Bobby (2006)',
#               'genre': 'Action|Comedy'},
#              46972: {'title': 'Night at the Museum (2006)',
#               'genre': 'Action|Comedy|Fantasy'},
#              46976: {'title': 'Stranger than Fiction (2006)',
#               'genre': 'Comedy|Drama|Fantasy|Romance'},
#              47044: {'title': 'Miami Vice (2006)',
#               'genre': 'Action|Crime|Drama|Thriller'},
#              47099: {'title': 'Pursuit of Happyness, The (2006)',
#               'genre': 'Drama'},
#              47200: {'title': 'Crank (2006)', 'genre': 'Action|Thriller'},
#              47518: {'title': 'Accepted (2006)', 'genre': 'Comedy'},
#              47610: {'title': 'Illusionist, The (2006)',
#               'genre': 'Drama|Fantasy|Mystery|Romance'},
#              47629: {'title': 'The Queen (2006)', 'genre': 'Drama'},
#              47997: {'title': 'Idiocracy (2006)',
#               'genre': 'Adventure|Comedy|Sci-Fi|Thriller'},
#              48043: {'title': 'Fountain, The (2006)',
#               'genre': 'Drama|Fantasy|Romance'},
#              48082: {'title': 'Science of Sleep, The (La science des rêves) (2006)',
#               'genre': 'Comedy|Drama|Fantasy|Romance'},
#              48304: {'title': 'Apocalypto (2006)',
#               'genre': 'Adventure|Drama|Thriller'},
#              48385: {'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)',
#               'genre': 'Comedy'},
#              48394: {'title': "Pan's Labyrinth (Laberinto del fauno, El) (2006)",
#               'genre': 'Drama|Fantasy|Thriller'},
#              48516: {'title': 'Departed, The (2006)',
#               'genre': 'Crime|Drama|Thriller'},
#              48738: {'title': 'Last King of Scotland, The (2006)',
#               'genre': 'Drama|Thriller'},
#              48774: {'title': 'Children of Men (2006)',
#               'genre': 'Action|Adventure|Drama|Sci-Fi|Thriller'},
#              48780: {'title': 'Prestige, The (2006)',
#               'genre': 'Drama|Mystery|Sci-Fi|Thriller'},
#              48783: {'title': 'Flags of Our Fathers (2006)', 'genre': 'Drama'},
#              48877: {'title': 'Saw III (2006)',
#               'genre': 'Crime|Horror|Thriller'},
#              49272: {'title': 'Casino Royale (2006)',
#               'genre': 'Action|Adventure|Thriller'},
#              49274: {'title': 'Happy Feet (2006)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              49278: {'title': 'Déjà Vu (Deja Vu) (2006)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              49286: {'title': 'Holiday, The (2006)',
#               'genre': 'Comedy|Romance'},
#              49530: {'title': 'Blood Diamond (2006)',
#               'genre': 'Action|Adventure|Crime|Drama|Thriller'},
#              49649: {'title': 'Eragon (2006)',
#               'genre': 'Action|Adventure|Fantasy'},
#              49651: {'title': 'Rocky Balboa (2006)', 'genre': 'Action|Drama'},
#              50068: {'title': 'Letters from Iwo Jima (2006)',
#               'genre': 'Drama'},
#              50794: {'title': "Smokin' Aces (2006)",
#               'genre': 'Action|Crime|Drama|Thriller'},
#              50872: {'title': 'Ratatouille (2007)',
#               'genre': 'Animation|Children|Drama'},
#              51077: {'title': 'Ghost Rider (2007)',
#               'genre': 'Action|Fantasy|Thriller'},
#              51084: {'title': 'Music and Lyrics (2007)',
#               'genre': 'Comedy|Romance'},
#              51086: {'title': 'Number 23, The (2007)',
#               'genre': 'Drama|Mystery|Thriller'},
#              51255: {'title': 'Hot Fuzz (2007)',
#               'genre': 'Action|Comedy|Crime|Mystery'},
#              51412: {'title': 'Next (2007)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              51540: {'title': 'Zodiac (2007)',
#               'genre': 'Crime|Drama|Thriller'},
#              51662: {'title': '300 (2007)', 'genre': 'Action|Fantasy'},
#              51935: {'title': 'Shooter (2007)',
#               'genre': 'Action|Drama|Thriller'},
#              52245: {'title': 'Blades of Glory (2007)',
#               'genre': 'Comedy|Romance'},
#              52281: {'title': 'Grindhouse (2007)',
#               'genre': 'Action|Crime|Horror|Sci-Fi|Thriller'},
#              52287: {'title': 'Meet the Robinsons (2007)',
#               'genre': 'Action|Adventure|Animation|Children|Comedy|Sci-Fi'},
#              52328: {'title': 'Sunshine (2007)',
#               'genre': 'Adventure|Drama|Sci-Fi|Thriller'},
#              52458: {'title': 'Disturbia (2007)', 'genre': 'Drama|Thriller'},
#              52604: {'title': 'Fracture (2007)',
#               'genre': 'Crime|Drama|Mystery|Thriller'},
#              52722: {'title': 'Spider-Man 3 (2007)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              52973: {'title': 'Knocked Up (2007)',
#               'genre': 'Comedy|Drama|Romance'},
#              52975: {'title': 'Hairspray (2007)', 'genre': 'Comedy|Drama'},
#              53000: {'title': '28 Weeks Later (2007)',
#               'genre': 'Horror|Sci-Fi|Thriller'},
#              53121: {'title': 'Shrek the Third (2007)',
#               'genre': 'Adventure|Animation|Children|Comedy|Fantasy'},
#              53125: {'title': "Pirates of the Caribbean: At World's End (2007)",
#               'genre': 'Action|Adventure|Comedy|Fantasy'},
#              53322: {'title': "Ocean's Thirteen (2007)",
#               'genre': 'Crime|Thriller'},
#              53464: {'title': 'Fantastic Four: Rise of the Silver Surfer (2007)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              53519: {'title': 'Death Proof (2007)',
#               'genre': 'Action|Adventure|Crime|Horror|Thriller'},
#              53894: {'title': 'Sicko (2007)', 'genre': 'Documentary|Drama'},
#              53953: {'title': '1408 (2007)', 'genre': 'Drama|Horror|Thriller'},
#              53972: {'title': 'Live Free or Die Hard (2007)',
#               'genre': 'Action|Adventure|Crime|Thriller'},
#              53993: {'title': 'Evan Almighty (2007)',
#               'genre': 'Comedy|Fantasy'},
#              53996: {'title': 'Transformers (2007)',
# ...
#              92535: {'title': 'Louis C.K.: Live at the Beacon Theater (2011)',
#               'genre': 'Comedy'},
#              93326: {'title': 'This Means War (2012)',
#               'genre': 'Action|Comedy|Romance'},
#              93363: {'title': 'John Carter (2012)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              93510: {'title': '21 Jump Street (2012)',
#               'genre': 'Action|Comedy|Crime'},
#              93840: {'title': 'Cabin in the Woods, The (2012)',
#               'genre': 'Comedy|Horror|Sci-Fi|Thriller'},
#              94677: {'title': 'Dictator, The (2012)', 'genre': 'Comedy'},
#              94777: {'title': 'Men in Black III (M.III.B.) (M.I.B.³) (2012)',
#               'genre': 'Action|Comedy|Sci-Fi'},
#              94864: {'title': 'Prometheus (2012)',
#               'genre': 'Action|Horror|Sci-Fi'},
#              94959: {'title': 'Moonrise Kingdom (2012)',
#               'genre': 'Comedy|Drama|Romance'},
#              95167: {'title': 'Brave (2012)',
#               'genre': 'Action|Adventure|Animation|Children'},
#              95441: {'title': 'Ted (2012)', 'genre': 'Comedy|Fantasy'},
#              95510: {'title': 'Amazing Spider-Man, The (2012)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              96079: {'title': 'Skyfall (2012)',
#               'genre': 'Action|Adventure|Thriller'},
#              96588: {'title': 'Pitch Perfect (2012)', 'genre': 'Comedy'},
#              96610: {'title': 'Looper (2012)', 'genre': 'Action|Crime|Sci-Fi'},
#              96737: {'title': 'Dredd (2012)', 'genre': 'Action|Sci-Fi'},
#              96821: {'title': 'Perks of Being a Wallflower, The (2012)',
#               'genre': 'Drama|Romance'},
#              96829: {'title': 'Hunt, The (Jagten) (2012)', 'genre': 'Drama'},
#              97225: {'title': 'Hotel Transylvania (2012)',
#               'genre': 'Animation|Children|Comedy'},
#              97304: {'title': 'Argo (2012)', 'genre': 'Drama|Thriller'},
#              97306: {'title': 'Seven Psychopaths (2012)',
#               'genre': 'Comedy|Crime'},
#              97752: {'title': 'Cloud Atlas (2012)', 'genre': 'Drama|Sci-Fi'},
#              97913: {'title': 'Wreck-It Ralph (2012)',
#               'genre': 'Animation|Comedy'},
#              97921: {'title': 'Silver Linings Playbook (2012)',
#               'genre': 'Comedy|Drama'},
#              97938: {'title': 'Life of Pi (2012)', 'genre': 'Adventure|Drama'},
#              98243: {'title': 'Rise of the Guardians (2012)',
#               'genre': 'Adventure|Animation|Children|Fantasy'},
#              98809: {'title': 'Hobbit: An Unexpected Journey, The (2012)',
#               'genre': 'Adventure|Fantasy'},
#              98961: {'title': 'Zero Dark Thirty (2012)',
#               'genre': 'Action|Drama|Thriller'},
#              99007: {'title': 'Warm Bodies (2013)',
#               'genre': 'Comedy|Horror|Romance'},
#              99112: {'title': 'Jack Reacher (2012)',
#               'genre': 'Action|Crime|Thriller'},
#              99114: {'title': 'Django Unchained (2012)',
#               'genre': 'Action|Drama'},
#              101864: {'title': 'Oblivion (2013)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              102123: {'title': 'This Is the End (2013)',
#               'genre': 'Action|Comedy'},
#              102125: {'title': 'Iron Man 3 (2013)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              102407: {'title': 'Great Gatsby, The (2013)', 'genre': 'Drama'},
#              102445: {'title': 'Star Trek Into Darkness (2013)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              102481: {'title': 'Internship, The (2013)', 'genre': 'Comedy'},
#              102903: {'title': 'Now You See Me (2013)',
#               'genre': 'Crime|Mystery|Thriller'},
#              103042: {'title': 'Man of Steel (2013)',
#               'genre': 'Action|Adventure|Fantasy|Sci-Fi'},
#              103141: {'title': 'Monsters University (2013)',
#               'genre': 'Adventure|Animation|Comedy'},
#              103228: {'title': 'Pacific Rim (2013)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              103249: {'title': 'World War Z (2013)',
#               'genre': 'Action|Drama|Horror'},
#              103253: {'title': 'Elysium (2013)',
#               'genre': 'Action|Drama|Sci-Fi'},
#              103335: {'title': 'Despicable Me 2 (2013)',
#               'genre': 'Animation|Children|Comedy'},
#              103341: {'title': "World's End, The (2013)",
#               'genre': 'Action|Comedy|Sci-Fi'},
#              103772: {'title': 'Wolverine, The (2013)',
#               'genre': 'Action|Adventure|Fantasy|Sci-Fi'},
#              104211: {'title': "We're the Millers (2013)",
#               'genre': 'Comedy|Crime'},
#              104241: {'title': 'Kick-Ass 2 (2013)',
#               'genre': 'Action|Comedy|Crime'},
#              104374: {'title': 'About Time (2013)',
#               'genre': 'Drama|Fantasy|Romance'},
#              104841: {'title': 'Gravity (2013)', 'genre': 'Action|Sci-Fi'},
#              104879: {'title': 'Prisoners (2013)',
#               'genre': 'Drama|Mystery|Thriller'},
#              104913: {'title': 'Rush (2013)', 'genre': 'Action|Drama'},
#              105504: {'title': 'Captain Phillips (2013)',
#               'genre': 'Adventure|Drama|Thriller'},
#              105844: {'title': '12 Years a Slave (2013)', 'genre': 'Drama'},
#              106002: {'title': "Ender's Game (2013)",
#               'genre': 'Action|Adventure|Sci-Fi'},
#              106072: {'title': 'Thor: The Dark World (2013)',
#               'genre': 'Action|Adventure|Fantasy'},
#              106100: {'title': 'Dallas Buyers Club (2013)', 'genre': 'Drama'},
#              106487: {'title': 'The Hunger Games: Catching Fire (2013)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              106489: {'title': 'Hobbit: The Desolation of Smaug, The (2013)',
#               'genre': 'Adventure|Fantasy'},
#              106696: {'title': 'Frozen (2013)',
#               'genre': 'Adventure|Animation|Comedy|Fantasy|Romance'},
#              106782: {'title': 'Wolf of Wall Street, The (2013)',
#               'genre': 'Comedy|Crime|Drama'},
#              106916: {'title': 'American Hustle (2013)',
#               'genre': 'Crime|Drama'},
#              106918: {'title': 'Secret Life of Walter Mitty, The (2013)',
#               'genre': 'Adventure|Comedy|Drama'},
#              106920: {'title': 'Her (2013)', 'genre': 'Drama|Romance|Sci-Fi'},
#              107348: {'title': 'Anchorman 2: The Legend Continues (2013)',
#               'genre': 'Comedy'},
#              107406: {'title': 'Snowpiercer (2013)',
#               'genre': 'Action|Drama|Sci-Fi'},
#              108190: {'title': 'Divergent (2014)',
#               'genre': 'Adventure|Romance|Sci-Fi'},
#              108932: {'title': 'The Lego Movie (2014)',
#               'genre': 'Action|Adventure|Animation|Children|Comedy|Fantasy'},
#              109374: {'title': 'Grand Budapest Hotel, The (2014)',
#               'genre': 'Comedy|Drama'},
#              109487: {'title': 'Interstellar (2014)', 'genre': 'Sci-Fi'},
#              110102: {'title': 'Captain America: The Winter Soldier (2014)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              110553: {'title': 'The Amazing Spider-Man 2 (2014)',
#               'genre': 'Action|Sci-Fi'},
#              111113: {'title': 'Neighbors (2014)', 'genre': 'Comedy'},
#              111360: {'title': 'Lucy (2014)', 'genre': 'Action|Sci-Fi'},
#              111362: {'title': 'X-Men: Days of Future Past (2014)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              111364: {'title': 'Godzilla (2014)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              111659: {'title': 'Maleficent (2014)',
#               'genre': 'Action|Adventure|Children'},
#              111743: {'title': 'A Million Ways to Die in the West (2014)',
#               'genre': 'Comedy'},
#              111759: {'title': 'Edge of Tomorrow (2014)',
#               'genre': 'Action|Sci-Fi'},
#              111781: {'title': 'Mission: Impossible - Rogue Nation (2015)',
#               'genre': 'Action|Adventure|Thriller'},
#              112138: {'title': '22 Jump Street (2014)',
#               'genre': 'Action|Comedy|Crime'},
#              112175: {'title': 'How to Train Your Dragon 2 (2014)',
#               'genre': 'Action|Adventure|Animation'},
#              112183: {'title': 'Birdman: Or (The Unexpected Virtue of Ignorance) (2014)',
#               'genre': 'Comedy|Drama'},
#              112290: {'title': 'Boyhood (2014)', 'genre': 'Drama'},
#              112552: {'title': 'Whiplash (2014)', 'genre': 'Drama'},
#              112556: {'title': 'Gone Girl (2014)', 'genre': 'Drama|Thriller'},
#              112623: {'title': 'Dawn of the Planet of the Apes (2014)',
#               'genre': 'Sci-Fi'},
#              112852: {'title': 'Guardians of the Galaxy (2014)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              114180: {'title': 'Maze Runner, The (2014)',
#               'genre': 'Action|Mystery|Sci-Fi'},
#              114662: {'title': 'American Sniper (2014)', 'genre': 'Action'},
#              114935: {'title': 'Predestination (2014)',
#               'genre': 'Action|Mystery|Sci-Fi|Thriller'},
#              115149: {'title': 'John Wick (2014)', 'genre': 'Action|Thriller'},
#              115210: {'title': 'Fury (2014)', 'genre': 'Action|Drama'},
#              115569: {'title': 'Nightcrawler (2014)',
#               'genre': 'Crime|Drama|Thriller'},
#              115617: {'title': 'Big Hero 6 (2014)',
#               'genre': 'Action|Animation|Comedy'},
#              115713: {'title': 'Ex Machina (2015)',
#               'genre': 'Drama|Sci-Fi|Thriller'},
#              116797: {'title': 'The Imitation Game (2014)',
#               'genre': 'Drama|Thriller'},
#              116823: {'title': 'The Hunger Games: Mockingjay - Part 1 (2014)',
#               'genre': 'Adventure|Sci-Fi|Thriller'},
#              116897: {'title': 'Wild Tales (2014)',
#               'genre': 'Comedy|Drama|Thriller'},
#              117176: {'title': 'The Theory of Everything (2014)',
#               'genre': 'Drama|Romance'},
#              117529: {'title': 'Jurassic World (2015)',
#               'genre': 'Action|Adventure|Drama|Sci-Fi|Thriller'},
#              117590: {'title': 'Horrible Bosses 2 (2014)',
#               'genre': 'Comedy|Crime'},
#              118696: {'title': 'The Hobbit: The Battle of the Five Armies (2014)',
#               'genre': 'Adventure|Fantasy'},
#              119141: {'title': 'The Interview (2014)',
#               'genre': 'Action|Comedy'},
#              119145: {'title': 'Kingsman: The Secret Service (2015)',
#               'genre': 'Action|Adventure|Comedy|Crime'},
#              120466: {'title': 'Chappie (2015)', 'genre': 'Action|Thriller'},
#              122882: {'title': 'Mad Max: Fury Road (2015)',
#               'genre': 'Action|Adventure|Sci-Fi|Thriller'},
#              122886: {'title': 'Star Wars: Episode VII - The Force Awakens (2015)',
#               'genre': 'Action|Adventure|Fantasy|Sci-Fi'},
#              122892: {'title': 'Avengers: Age of Ultron (2015)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              122900: {'title': 'Ant-Man (2015)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              122904: {'title': 'Deadpool (2016)',
#               'genre': 'Action|Adventure|Comedy|Sci-Fi'},
#              122906: {'title': 'Black Panther (2017)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              122912: {'title': 'Avengers: Infinity War - Part I (2018)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              122916: {'title': 'Thor: Ragnarok (2017)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              122918: {'title': 'Guardians of the Galaxy 2 (2017)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              122920: {'title': 'Captain America: Civil War (2016)',
#               'genre': 'Action|Sci-Fi|Thriller'},
#              122922: {'title': 'Doctor Strange (2016)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              122924: {'title': 'X-Men: Apocalypse (2016)',
#               'genre': 'Action|Adventure|Fantasy|Sci-Fi'},
#              122926: {'title': 'Untitled Spider-Man Reboot (2017)',
#               'genre': 'Action|Adventure|Fantasy'},
#              129354: {'title': 'Focus (2015)',
#               'genre': 'Comedy|Crime|Drama|Romance'},
#              134130: {'title': 'The Martian (2015)',
#               'genre': 'Adventure|Drama|Sci-Fi'},
#              134368: {'title': 'Spy (2015)', 'genre': 'Action|Comedy|Crime'},
#              134393: {'title': 'Trainwreck (2015)', 'genre': 'Comedy|Romance'},
#              134853: {'title': 'Inside Out (2015)',
#               'genre': 'Adventure|Animation|Children|Comedy|Drama|Fantasy'},
#              135133: {'title': 'The Hunger Games: Mockingjay - Part 2 (2015)',
#               'genre': 'Adventure|Sci-Fi'},
#              135143: {'title': 'Fantastic Beasts and Where to Find Them (2016)',
#               'genre': 'Fantasy'},
#              135536: {'title': 'Suicide Squad (2016)',
#               'genre': 'Action|Crime|Sci-Fi'},
#              135569: {'title': 'Star Trek Beyond (2016)',
#               'genre': 'Action|Adventure|Sci-Fi'},
#              135887: {'title': 'Minions (2015)',
#               'genre': 'Adventure|Animation|Children|Comedy'},
#              136020: {'title': 'Spectre (2015)',
#               'genre': 'Action|Adventure|Crime'},
#              136864: {'title': 'Batman v Superman: Dawn of Justice (2016)',
#               'genre': 'Action|Adventure|Fantasy|Sci-Fi'},
#              137857: {'title': 'The Jungle Book (2016)',
#               'genre': 'Adventure|Drama|Fantasy'},
#              138036: {'title': 'The Man from U.N.C.L.E. (2015)',
#               'genre': 'Action|Adventure|Comedy'},
#              139385: {'title': 'The Revenant (2015)',
#               'genre': 'Adventure|Drama'},
#              139644: {'title': 'Sicario (2015)',
#               'genre': 'Crime|Drama|Mystery'},
#              140110: {'title': 'The Intern (2015)', 'genre': 'Comedy'},
#              142488: {'title': 'Spotlight (2015)', 'genre': 'Thriller'},
#              143355: {'title': 'Wonder Woman (2017)',
#               'genre': 'Action|Adventure|Fantasy'},
#              148626: {'title': 'Big Short, The (2015)', 'genre': 'Drama'},
#              150548: {'title': 'Sherlock: The Abominable Bride (2016)',
#               'genre': 'Action|Crime|Drama|Mystery|Thriller'},
#              152077: {'title': '10 Cloverfield Lane (2016)',
#               'genre': 'Thriller'},
#              152081: {'title': 'Zootopia (2016)',
#               'genre': 'Action|Adventure|Animation|Children|Comedy'},
#              157296: {'title': 'Finding Dory (2016)',
#               'genre': 'Adventure|Animation|Comedy'},
#              158238: {'title': 'The Nice Guys (2016)',
#               'genre': 'Crime|Mystery|Thriller'},
#              159093: {'title': 'Now You See Me 2 (2016)',
#               'genre': 'Action|Comedy|Thriller'},
#              164179: {'title': 'Arrival (2016)', 'genre': 'Sci-Fi'},
#              166461: {'title': 'Moana (2016)',
#               'genre': 'Adventure|Animation|Children|Comedy|Fantasy'},
#              166528: {'title': 'Rogue One: A Star Wars Story (2016)',
#               'genre': 'Action|Adventure|Fantasy|Sci-Fi'},
#              166643: {'title': 'Hidden Figures (2016)', 'genre': 'Drama'},
#              168250: {'title': 'Get Out (2017)', 'genre': 'Horror'},
#              168252: {'title': 'Logan (2017)', 'genre': 'Action|Sci-Fi'},
#              174055: {'title': 'Dunkirk (2017)',
#               'genre': 'Action|Drama|Thriller'},
#              176371: {'title': 'Blade Runner 2049 (2017)', 'genre': 'Sci-Fi'},
#              177765: {'title': 'Coco (2017)',
#               'genre': 'Adventure|Animation|Children'},
#              179819: {'title': 'Star Wars: The Last Jedi (2017)',
#               'genre': 'Action|Adventure|Fantasy|Sci-Fi'},
#              187593: {'title': 'Deadpool 2 (2018)',
#               'genre': 'Action|Comedy|Sci-Fi'}})

# %% [markdown]
# **Counting number of user and item features**

# %%
num_user_features = len(user_features) - 3  #removing userid, rating_count and average rating
num_item_features = len(item_features) - 1  #removing movieid and we didnot remove year , cause year represents the era of a movie
print('The number of user features is:', num_user_features)
print('The number of item features is:', num_item_features)
# Out:
# The number of user features is: 14
# The number of item features is: 16

# %% [markdown]
# **Converting the item,user and y dataframe into numpy array**

# %%
item_train_array = np.array(item_train)
user_train_array = np.array(user_train)
y_train_array = np.array(y_train)

# %% [markdown]
# **Splitting datas into train and test dataset**

# %%
item_train,item_test = train_test_split(item_train_array,train_size = 0.80, shuffle=True, random_state = 1)
user_train,user_test = train_test_split(user_train_array,train_size = 0.80, shuffle=True, random_state = 1)
y_train,y_test = train_test_split(y_train_array,train_size = 0.80, shuffle=True, random_state = 1)

# %% [markdown]
# **Standard scaling of user, item dataset and minmax scaling of rating value**

# %%
user_scalar = StandardScaler()
user_scalar.fit(user_train)
user_train_scaled = user_scalar.transform(user_train)  #scaling the user training dataset
user_test_scaled = user_scalar.transform(user_test)    #scaling the user test dataset

item_scalar = StandardScaler()
item_scalar.fit(item_train)
item_train_scaled = item_scalar.transform(item_train)  #scaling the user training dataset
item_test_scaled = item_scalar.transform(item_test)    #scaling the user test dataset

y_scalar = MinMaxScaler((-1,1))
y_scalar.fit(y_train)
y_train_scaled = y_scalar.transform(y_train)  #scaling the user training dataset
y_test_scaled = y_scalar.transform(y_test)    #scaling the user test dataset

# %% [markdown]
# **Neural Network Architecture**

# %%
num_outputs = 32  #the number of final output of our neural network
tf.random.set_seed(1)
user_nn = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(num_outputs)
])
item_nn = tf.keras.models.Sequential([
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(num_outputs)
])
input_user = tf.keras.layers.Input(shape =(num_user_features,))  
vu = user_nn(input_user) #passing the number of user features in the user neural network
vu = tf.keras.ops.normalize(vu, axis=1)  #applying the l2 normalization on user vector

input_item = tf.keras.layers.Input(shape =(num_item_features,))  
vm = item_nn(input_item) #passing the number of item features in the item neural network
vm = tf.keras.ops.normalize(vm, axis=1)  #applying the l2 normalization on item vector

output = tf.keras.layers.Dot(axes=1)([vu,vm])
model = tf.keras.Model([input_user, input_item], output)  #creating the model with the passed input and output

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 14)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_2 (InputLayer)    │ (None, 16)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequential (Sequential)       │ (None, 32)                │          40,864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequential_1 (Sequential)     │ (None, 32)                │          41,376 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ normalize (Normalize)         │ (None, 32)                │               0 │ sequential[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ normalize_1 (Normalize)       │ (None, 32)                │               0 │ sequential_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dot (Dot)                     │ (None, 1)                 │               0 │ normalize[0][0],           │
# │                               │                           │                 │ normalize_1[0][0]          │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 82,240 (321.25 KB)
#  Trainable params: 82,240 (321.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Training the neural network**

# %%
tf.random.set_seed(1)
cost_function = tf.keras.losses.MeanSquaredError()  #we are using MSE as a cost function for our nn model
opt = keras.optimizers.Adam(learning_rate = 0.01)
model.compile(optimizer = opt, loss = cost_function)  #setting the cost function as well as the optimization for the neural network

model.fit([user_train_scaled[:,user_index:], item_train_scaled[:,item_index:]],y_train_scaled,epochs = 30)  #training the neural network model, and we are only selecting the required features from both user and item training dataset
model.evaluate([user_test_scaled[:,user_index:], item_test_scaled[:,item_index:]],y_test_scaled)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - loss: 0.1235
# Epoch 2/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 0.1150
# Epoch 3/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.1094
# Epoch 4/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.1051
# Epoch 5/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.1019
# Epoch 6/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0994
# Epoch 7/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0970
# Epoch 8/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0949
# Epoch 9/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 0.0930
# Epoch 10/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 0.0912
# Epoch 11/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 0.0894
# Epoch 12/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - loss: 0.0877
# Epoch 13/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0862
# Epoch 14/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0849
# Epoch 15/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0836
# Epoch 16/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0826
# Epoch 17/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0815
# Epoch 18/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 0.0805
# Epoch 19/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0797
# Epoch 20/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0788
# Epoch 21/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0780
# Epoch 22/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0773
# Epoch 23/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0765
# Epoch 24/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0757
# Epoch 25/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0751
# Epoch 26/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0745
# Epoch 27/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0738
# Epoch 28/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0733
# Epoch 29/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0727
# Epoch 30/30
# 1273/1273 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 0.0722
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0846
# 0.08463720977306366

# %% [markdown]
# **Creation of new user ratings**

# %%
new_user_id = 5000
new_rating_ave = 0.0
new_action = 0.0
new_adventure = 5.0
new_animation = 0.0
new_childrens = 0.0
new_comedy = 0.0
new_crime = 0.0
new_documentary = 0.0
new_drama = 0.0
new_fantasy = 5.0
new_horror = 0.0
new_mystery = 0.0
new_romance = 0.0
new_scifi = 0.0
new_thriller = 0.0
new_rating_count = 3

user_vec = np.array([[new_user_id, new_rating_count, new_rating_ave,
                      new_action, new_adventure, new_animation, new_childrens,
                      new_comedy, new_crime, new_documentary,
                      new_drama, new_fantasy, new_horror, new_mystery,
                      new_romance, new_scifi, new_thriller]])

# %%
item_vecs_array = np.array(item_vecs)  #this is the item dataset which we will use for the predition of ratings done by the new user
item_vecs_array
# Out:
# array([[4.05400000e+03, 2.00100000e+03, 2.84375000e+00, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.06900000e+03, 2.00100000e+03, 2.90909091e+00, ...,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.14800000e+03, 2.00100000e+03, 2.93589744e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [1.77765000e+05, 2.01700000e+03, 3.53846154e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.79819000e+05, 2.01700000e+03, 3.12500000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [1.87593000e+05, 2.01800000e+03, 3.87500000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00]], shape=(847, 17))

# %%
user_vecs = gen_newuser_data(user_vec,len(item_vecs_array))  #here we are making the same size of user vector to match with that of item vector or movie dataset
user_vecs
# Out:
# array([[5.e+03, 3.e+00, 0.e+00, ..., 0.e+00, 0.e+00, 0.e+00],
#        [5.e+03, 3.e+00, 0.e+00, ..., 0.e+00, 0.e+00, 0.e+00],
#        [5.e+03, 3.e+00, 0.e+00, ..., 0.e+00, 0.e+00, 0.e+00],
#        ...,
#        [5.e+03, 3.e+00, 0.e+00, ..., 0.e+00, 0.e+00, 0.e+00],
#        [5.e+03, 3.e+00, 0.e+00, ..., 0.e+00, 0.e+00, 0.e+00],
#        [5.e+03, 3.e+00, 0.e+00, ..., 0.e+00, 0.e+00, 0.e+00]],
#       shape=(847, 17))

# %% [markdown]
# **Scaling of user as well as movie vector**

# %%
#using the trained scalar to transform both the user as well as item vector
scaled_user_vecs = user_scalar.transform(user_vecs)  
scaled_user_vecs
scaled_item_vecs = item_scalar.transform(item_vecs_array)
scaled_item_vecs
# Out:
# array([[-0.94788869, -1.1989544 , -1.98286105, ...,  2.49684357,
#         -0.50803289, -0.6593247 ],
#        [-0.94749159, -1.1989544 , -1.81467973, ...,  2.49684357,
#         -0.50803289, -0.6593247 ],
#        [-0.94540021, -1.1989544 , -1.74568226, ..., -0.40050567,
#         -0.50803289,  1.51670339],
#        ...,
#        [ 3.65079032,  2.82057147, -0.19473926, ..., -0.40050567,
#         -0.50803289, -0.6593247 ],
#        [ 3.70516619,  2.82057147, -1.25895015, ..., -0.40050567,
#          1.9683765 , -0.6593247 ],
#        [ 3.91096853,  3.07179184,  0.67147891, ..., -0.40050567,
#          1.9683765 , -0.6593247 ]], shape=(847, 17))

# %% [markdown]
# **Making prediction or recommendation of movies to this new user**

# %%
Y_value = model.predict([scaled_user_vecs[:,user_index:], scaled_item_vecs[:,item_index:]])  #prediction of model takes only one argument
#since while training the model, the rating value was scaled.
#we are unscaling the rating value here 
unscaled_y_value = y_scalar.inverse_transform(Y_value)
unscaled_y_value
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# array([[2.30365  ],
#        [2.5488174],
#        [2.3738446],
#        [2.4488757],
#        [2.5492074],
#        [2.316119 ],
#        [1.604363 ],
#        [2.363719 ],
#        [2.2746596],
#        [3.5315335],
#        [2.0324225],
#        [2.5711956],
#        [2.7402167],
#        [2.6805944],
#        [2.129706 ],
#        [2.8405516],
#        [2.6995955],
#        [3.399695 ],
#        [2.0278065],
#        [2.8075318],
#        [1.9198791],
#        [2.2380474],
#        [1.9463569],
#        [3.2247415],
#        [2.275575 ],
#        [1.9800935],
#        [2.0894914],
#        [1.8923161],
#        [2.2207794],
#        [2.2119677],
#        [2.989422 ],
#        [2.799542 ],
#        [2.5059829],
#        [2.5060499],
#        [2.3427975],
#        [2.5123549],
#        [2.599134 ],
#        [2.676641 ],
#        [2.351071 ],
#        [2.4891424],
#        [2.5242872],
#        [2.479194 ],
#        [2.2903454],
#        [2.2903316],
#        [2.7192698],
#        [2.7889454],
#        [2.7996836],
#        [1.494799 ],
#        [1.6908025],
#        [3.0880857],
#        [2.512655 ],
#        [2.5949852],
#        [2.4608936],
#        [3.3255987],
#        [2.4985032],
#        [3.1209304],
#        [4.2666698],
#        [2.3777392],
#        [2.666195 ],
#        [2.5679932],
#        [2.222151 ],
#        [2.420801 ],
#        [2.7958534],
#        [3.286873 ],
#        [2.142694 ],
#        [1.3378253],
#        [2.7196338],
#        [2.8176377],
#        [3.8903534],
#        [2.6434383],
#        [2.5494099],
#        [2.8163564],
#        [3.3132062],
#        [2.6212234],
#        [1.9679463],
#        [2.206128 ],
#        [3.360056 ],
#        [3.2880416],
#        [3.5661912],
#        [1.991961 ],
#        [2.2840793],
#        [2.2518172],
#        [2.4926083],
#        [2.5404983],
#        [3.2784698],
#        [2.2227855],
#        [2.4447649],
#        [3.2056625],
#        [2.110701 ],
#        [2.0911822],
#        [1.8014756],
#        [2.0688922],
#        [1.62568  ],
#        [2.2420905],
#        [2.4477072],
#        [2.3780315],
#        [2.5335176],
#        [2.8593817],
#        [1.8970813],
#        [1.8803189],
#        [3.1367195],
#        [2.8258674],
#        [2.3951018],
#        [2.9027405],
#        [1.903265 ],
#        [2.0636663],
#        [3.3584168],
#        [2.6707642],
#        [2.9732842],
#        [1.4743598],
#        [2.540207 ],
#        [2.3925269],
#        [2.4851604],
#        [2.2075877],
#        [2.4075174],
#        [1.5582365],
#        [2.296126 ],
#        [2.0450518],
#        [1.7798519],
#        [2.4033854],
#        [2.6450036],
#        [2.35652  ],
#        [3.1840353],
#        [2.6990535],
#        [2.1126492],
#        [2.1055286],
#        [3.4292269],
#        [2.7565343],
#        [2.6657476],
#        [2.8612537],
#        [2.2174618],
#        [2.2416375],
#        [2.3713071],
#        [4.205541 ],
#        [1.5625253],
#        [2.5618813],
#        [1.7053167],
#        [2.951778 ],
#        [2.8653882],
#        [2.3547678],
#        [2.5601919],
#        [2.2933838],
#        [3.9993885],
#        [2.6242688],
#        [2.2049305],
#        [2.856635 ],
#        [2.7046943],
#        [2.6223917],
#        [2.1156456],
#        [2.7288582],
#        [2.004994 ],
#        [3.0699885],
#        [2.389865 ],
#        [1.8586173],
#        [2.8659847],
#        [2.705278 ],
#        [2.0068393],
#        [2.6589074],
#        [2.628205 ],
#        [1.8912002],
#        [3.1594558],
#        [2.546547 ],
#        [2.469888 ],
#        [2.8410244],
#        [3.1874058],
#        [1.3807356],
#        [3.445501 ],
#        [3.4128387],
#        [2.7942352],
#        [2.532732 ],
#        [2.6750486],
#        [3.583491 ],
#        [2.540349 ],
#        [1.8814219],
#        [2.595622 ],
#        [1.946036 ],
#        [2.2460048],
#        [1.851346 ],
#        [2.4684591],
#        [2.0020416],
#        [2.3802488],
#        [3.901236 ],
#        [2.5967255],
#        [2.3189697],
#        [1.6739888],
#        [2.1156378],
#        [2.2378862],
#        [2.529826 ],
#        [2.5455992],
#        [3.066928 ],
#        [1.8432124],
#        [3.1229558],
#        [2.7165797],
#        [2.5739896],
#        [2.195039 ],
#        [2.9562552],
#        [3.2443743],
#        [2.8233187],
#        [1.8314784],
#        [2.6237376],
#        [2.681368 ],
#        [2.6071508],
#        [2.5231924],
#        [2.772132 ],
#        [2.7772627],
#        [3.1339254],
#        [1.7410561],
#        [2.1986072],
#        [2.5377793],
#        [3.5187087],
#        [2.8786652],
#        [2.8656728],
#        [2.5058675],
#        [2.2936535],
#        [2.521994 ],
#        [3.3624225],
#        [2.7215471],
#        [3.3012142],
#        [2.7190728],
#        [2.7998905],
#        [2.3915577],
#        [1.9588171],
#        [3.677014 ],
#        [2.38377  ],
#        [3.089462 ],
#        [2.262141 ],
#        [1.9419703],
#        [2.4578023],
#        [2.63826  ],
#        [1.6961294],
#        [2.2622802],
#        [2.5537386],
#        [3.031299 ],
#        [2.1623182],
#        [2.698787 ],
#        [2.12604  ],
#        [3.1432106],
#        [1.7849963],
#        [2.667815 ],
#        [2.5274215],
#        [2.2785983],
#        [2.7890668],
#        [3.5043776],
#        [3.070286 ],
#        [2.4724894],
#        [3.0612552],
#        [2.703045 ],
#        [2.8326719],
#        [2.5414855],
#        [2.4687462],
#        [2.7220886],
#        [2.9826236],
#        [2.7415667],
#        [2.6989887],
#        [4.159314 ],
#        [2.9730515],
#        [2.331575 ],
#        [1.9126775],
#        [2.5793478],
#        [2.595069 ],
#        [2.6673126],
#        [2.6591668],
#        [2.036005 ],
#        [2.4767766],
#        [3.343844 ],
#        [2.1621642],
#        [2.2547033],
#        [2.8438747],
#        [3.0220652],
#        [3.1095927],
#        [1.6757817],
#        [2.141549 ],
#        [2.8557138],
#        [2.7412426],
#        [2.2960136],
#        [2.3396325],
#        [2.2574654],
#        [2.470107 ],
#        [3.0210712],
#        [2.4244783],
#        [1.6448189],
#        [2.618683 ],
#        [1.964265 ],
#        [2.5100691],
#        [2.2780845],
#        [2.8740704],
#        [2.689367 ],
#        [2.5825531],
#        [2.4938722],
#        [3.7030513],
#        [3.640235 ],
#        [2.5178998],
#        [2.4501998],
#        [2.3323307],
#        [2.3677099],
#        [2.1809845],
#        [2.1737974],
#        [3.146854 ],
#        [2.164076 ],
#        [1.9992801],
#        [1.9591595],
#        [2.2781527],
#        [2.8779457],
#        [3.1594582],
#        [2.6646986],
#        [2.60394  ],
#        [2.1577299],
#        [3.4993522],
#        [1.9537972],
#        [2.5871787],
#        [2.5577369],
#        [2.0582118],
#        [3.5051682],
#        [2.3655694],
#        [1.9936433],
#        [2.376226 ],
#        [2.568191 ],
#        [2.1484656],
#        [2.5973098],
#        [2.696914 ],
#        [2.847132 ],
#        [2.7270858],
#        [2.5665033],
#        [2.3743796],
#        [2.2951097],
#        [1.6911165],
#        [2.6197112],
#        [2.1333842],
#        [2.1380305],
#        [2.7425516],
#        [2.5810485],
#        [2.2817326],
#        [2.5727801],
#        [2.6914458],
#        [3.0066197],
#        [2.3521903],
#        [2.5073335],
#        [2.8172536],
#        [2.4536462],
#        [3.0018408],
#        [2.3464797],
#        [3.413531 ],
#        [2.3811777],
#        [1.9415146],
#        [3.0437858],
#        [2.8561876],
#        [1.6515706],
#        [2.362008 ],
#        [2.6429105],
#        [2.2544563],
#        [2.136509 ],
#        [2.6091604],
#        [2.3473284],
#        [2.0565586],
#        [2.2512228],
#        [2.2823958],
#        [2.7499568],
#        [3.1825268],
#        [2.80689  ],
#        [2.9769652],
#        [2.0579584],
#        [2.6283746],
#        [2.4023342],
#        [2.321565 ],
#        [1.6517274],
#        [2.0551796],
#        [2.2145934],
#        [4.370626 ],
#        [2.2607307],
#        [2.0423033],
#        [2.0331728],
#        [4.3134828],
#        [2.9059534],
#        [2.8047132],
#        [2.1662667],
#        [2.8376756],
#        [2.960626 ],
#        [2.2657049],
#        [2.1456203],
#        [2.8644342],
#        [2.6211987],
#        [2.0278718],
#        [2.2643902],
#        [2.9625628],
#        [2.9621968],
#        [2.3410294],
#        [2.1410422],
#        [1.645407 ],
#        [2.1463318],
#        [2.8495169],
#        [2.312669 ],
#        [2.0888133],
#        [2.4055789],
#        [2.0016978],
#        [2.7532551],
#        [2.0150025],
#        [2.1618037],
#        [2.5953388],
#        [2.3823059],
#        [3.7472386],
#        [2.9222724],
#        [2.0567057],
#        [2.9365427],
#        [2.195551 ],
#        [2.4535303],
#        [2.6481402],
#        [1.5897187],
#        [2.2143755],
#        [2.0079558],
#        [3.0124753],
#        [2.7607574],
#        [2.0603232],
#        [2.541696 ],
#        [1.9123162],
#        [2.5316956],
#        [3.271206 ],
#        [2.531947 ],
#        [2.6013658],
#        [2.3936195],
#        [2.8198168],
#        [2.2862163],
#        [2.6073039],
#        [2.093474 ],
#        [2.636686 ],
#        [2.1069636],
#        [3.2951374],
#        [2.7821805],
#        [2.398884 ],
#        [2.4570317],
#        [3.4360714],
#        [1.5540226],
#        [2.4293296],
#        [2.739917 ],
#        [2.466121 ],
#        [1.9355432],
#        [2.0801115],
#        [2.5267158],
#        [2.2869291],
#        [2.712878 ],
#        [1.9352901],
#        [2.5503025],
#        [1.7998782],
#        [3.1722162],
#        [2.193886 ],
#        [1.8955451],
#        [3.739542 ],
#        [2.8169832],
#        [2.5375311],
#        [1.6786964],
#        [1.9206053],
#        [2.4936695],
#        [1.81896  ],
#        [1.7693844],
#        [2.4526086],
#        [2.871962 ],
#        [2.3541684],
#        [1.64809  ],
#        [2.0776725],
#        [3.5191436],
#        [2.1476676],
#        [2.3902292],
#        [2.3445153],
#        [2.9412036],
#        [1.447836 ],
#        [2.5811284],
#        [2.3252163],
#        [2.4646232],
#        [4.226018 ],
#        [2.941771 ],
#        [2.9310226],
#        [3.5608919],
#        [2.3089855],
#        [2.9703689],
#        [2.9289484],
#        [3.393408 ],
#        [1.790538 ],
#        [3.0181355],
#        [2.535233 ],
#        [2.1271532],
#        [2.308152 ],
#        [2.3181934],
#        [2.9585745],
#        [1.8897665],
#        [2.0246632],
#        [2.3984241],
#        [2.7446609],
#        [3.0764499],
#        [2.5462558],
#        [3.1197803],
#        [2.1220064],
#        [2.522654 ],
#        [2.838058 ],
#        [2.6613138],
#        [1.885725 ],
#        [3.0042179],
#        [3.3317294],
#        [1.9578054],
#        [2.9884877],
#        [2.9203653],
#        [2.293705 ],
#        [1.5498391],
#        [2.3859394],
#        [2.65873  ],
#        [2.2912977],
#        [2.7349646],
#        [2.8043728],
#        [2.6952746],
#        [3.983557 ],
#        [2.4076028],
#        [2.8207803],
#        [2.4920192],
#        [2.508512 ],
#        [2.64648  ],
#        [2.787846 ],
#        [3.0791967],
#        [1.6594802],
#        [3.2198863],
#        [2.1565402],
#        [2.695774 ],
#        [3.2181969],
#        [2.4996514],
#        [4.0329814],
#        [4.328968 ],
#        [2.2189715],
#        [1.9832717],
#        [1.9659305],
#        [2.460289 ],
#        [2.1843102],
#        [2.7059107],
#        [1.905363 ],
#        [2.9454043],
#        [2.0224493],
#        [2.318043 ],
#        [2.8572915],
#        [2.66367  ],
#        [2.1872826],
#        [2.7089791],
#        [2.7063625],
#        [2.6723702],
#        [2.0619926],
#        [2.4469836],
#        [2.605134 ],
#        [2.8841493],
#        [2.7051744],
#        [2.6057658],
#        [2.3066983],
#        [2.6869555],
#        [2.1504865],
#        [2.631218 ],
#        [2.0057313],
#        [2.9186213],
#        [2.7051   ],
#        [2.6483903],
#        [3.228021 ],
#        [2.6817148],
#        [1.4802856],
#        [2.6105037],
#        [2.1647065],
#        [3.6396549],
#        [2.3800042],
#        [1.5885781],
#        [1.8305515],
#        [3.0071633],
#        [2.6986387],
#        [2.4004762],
#        [2.240394 ],
#        [2.2457223],
#        [2.2438025],
#        [2.523515 ],
#        [2.7187953],
#        [2.0878925],
#        [3.2599075],
#        [1.9763994],
#        [2.9466045],
#        [2.1606174],
#        [3.3731196],
#        [2.341992 ],
#        [2.8862457],
#        [2.8598423],
#        [2.310092 ],
#        [1.9499716],
#        [2.802098 ],
#        [2.7300153],
#        [4.093717 ],
#        [3.0852911],
#        [2.802098 ],
#        [2.5100138],
#        [1.9291409],
#        [2.1370335],
#        [2.0189538],
#        [2.1547995],
#        [2.3383434],
#        [2.2176445],
#        [2.2912023],
#        [2.5012686],
#        [2.385698 ],
#        [2.727643 ],
#        [1.9588443],
#        [2.756946 ],
#        [2.2526457],
#        [2.9103196],
#        [3.1000676],
#        [2.0995467],
#        [2.1714506],
#        [2.902676 ],
#        [2.5011127],
#        [3.7105808],
#        [2.2364094],
#        [2.118725 ],
#        [2.7586255],
#        [2.6980767],
#        [3.4725518],
#        [3.3060489],
#        [2.7313094],
#        [2.1229093],
#        [3.4829154],
#        [1.8430359],
#        [2.5734754],
#        [3.0097284],
#        [2.4078684],
#        [2.7276604],
#        [3.1875818],
#        [1.6442319],
#        [2.0862083],
#        [1.6508343],
#        [3.329907 ],
#        [2.835052 ],
#        [2.7198741],
#        [2.1302893],
#        [3.1775286],
#        [2.9309044],
#        [2.0099065],
#        [2.7418635],
#        [2.2898176],
#        [2.2878695],
#        [1.5484746],
#        [4.150948 ],
#        [2.773355 ],
#        [2.4256098],
#        [2.7621973],
#        [2.7021704],
#        [2.2479563],
#        [3.0114126],
#        [2.755825 ],
#        [1.956443 ],
#        [1.6170907],
#        [2.355331 ],
#        [2.1369302],
#        [1.5216744],
#        [1.5240552],
#        [2.123155 ],
#        [1.0840113],
#        [3.7867513],
#        [1.7097685],
#        [3.0328207],
#        [3.5209174],
#        [3.0072155],
#        [2.7321925],
#        [1.8325663],
#        [3.659548 ],
#        [2.7700589],
#        [2.2629685],
#        [2.268986 ],
#        [2.3131747],
#        [3.9690711],
#        [1.7945038],
#        [3.5389884],
#        [2.7686818],
#        [2.0633562],
#        [1.7646691],
#        [2.2435524],
#        [2.790148 ],
#        [2.1789982],
#        [2.7800457],
#        [3.2614536],
#        [2.870966 ],
#        [2.1656022],
#        [2.769076 ],
#        [2.4197173],
#        [2.362137 ],
#        [3.5632725],
#        [2.5366569],
#        [1.7547098],
#        [2.8283372],
#        [3.4405994],
#        [3.1148531],
#        [2.0176346],
#        [3.7913458],
#        [2.950206 ],
#        [1.3880843],
#        [2.623334 ],
#        [3.240519 ],
#        [2.4285133],
#        [2.8708825],
#        [2.8704298],
#        [2.1697493],
#        [2.7641816],
#        [1.7590039],
#        [1.8462596],
#        [2.6702254],
#        [2.79445  ],
#        [2.8348656],
#        [2.917935 ],
#        [3.2798302],
#        [2.8163743],
#        [2.391312 ],
#        [2.530355 ],
#        [2.724601 ],
#        [2.970147 ],
#        [2.6480422],
#        [2.2646334],
#        [2.3667495],
#        [2.5047343],
#        [3.113923 ],
#        [2.2042892],
#        [2.5189605],
#        [3.888583 ],
#        [4.30519  ],
#        [2.7385395],
#        [1.8661435],
#        [2.7700925],
#        [2.2935543],
#        [3.0071547],
#        [2.2576044],
#        [2.7769823],
#        [2.892108 ],
#        [3.2080147],
#        [2.7553406],
#        [2.0657895],
#        [3.6823301],
#        [3.6489732],
#        [3.1720762],
#        [2.9394715],
#        [2.4418383],
#        [2.9876757],
#        [1.8217647],
#        [3.7305999],
#        [2.61509  ],
#        [2.395711 ],
#        [3.072847 ],
#        [2.4912949],
#        [2.3334417],
#        [2.1672251],
#        [2.5649881],
#        [3.0745628],
#        [3.0746958],
#        [3.6446507],
#        [2.9318202],
#        [3.1837327],
#        [4.173861 ],
#        [2.4345953],
#        [2.6252825],
#        [2.3210754],
#        [2.4417048],
#        [2.3637729],
#        [2.610551 ],
#        [2.1831203],
#        [2.7926688],
#        [3.1390507],
#        [2.362148 ],
#        [3.1855562],
#        [3.2260988],
#        [2.5316713],
#        [2.4861593],
#        [2.581688 ],
#        [3.2182753],
#        [2.6219373],
#        [2.7029607],
#        [2.0017653],
#        [2.7496808],
#        [3.0908601],
#        [2.6502562],
#        [3.1541338],
#        [2.145082 ],
#        [3.0376923],
#        [3.0134966],
#        [1.8910161],
#        [3.0841293],
#        [3.1617835],
#        [2.7806416],
#        [2.746762 ],
#        [2.6969566],
#        [2.9715066],
#        [2.172111 ],
#        [2.504054 ],
#        [3.2903202],
#        [2.0035806],
#        [2.3603625],
#        [3.2461772],
#        [2.4037848],
#        [2.7440624],
#        [3.038741 ],
#        [2.6088142],
#        [4.047949 ],
#        [2.0547166],
#        [2.9998808],
#        [1.8144804],
#        [3.4585886],
#        [3.857717 ],
#        [3.2235417],
#        [3.231251 ],
#        [2.9672759],
#        [3.2156005],
#        [3.1080663],
#        [3.1011252],
#        [3.1371694],
#        [2.6777153],
#        [3.2440634],
#        [3.5011866],
#        [4.0028014],
#        [1.8521662],
#        [2.6302524],
#        [2.6789484],
#        [1.8736411],
#        [3.1100235],
#        [3.2976232],
#        [3.9365363],
#        [2.392505 ],
#        [3.206638 ],
#        [2.2062151],
#        [2.5473602],
#        [2.736019 ],
#        [4.3526483],
#        [2.7124376],
#        [2.781957 ],
#        [3.148192 ],
#        [2.9386547],
#        [3.2550752],
#        [3.6468008],
#        [3.096949 ],
#        [3.1035419],
#        [1.8493743],
#        [2.620757 ],
#        [3.5829504],
#        [2.8389874],
#        [2.3985991],
#        [3.206802 ],
#        [2.8371487],
#        [3.8041563],
#        [3.2646   ],
#        [2.8418508],
#        [2.917948 ],
#        [1.5407978],
#        [3.2190762],
#        [3.3708723],
#        [3.5264947],
#        [2.5805871]], dtype=float32)

# %% [markdown]
# **Sorting the predicted rating values**

# %%
sorted_indexes = np.argsort(-unscaled_y_value,axis = 0).reshape(-1).tolist() #here we are saving the indexes of the rating value based on descending order, and we are using -ve sign cause .argsort sort values in ascending order 
sorted_rating_values = unscaled_y_value[sorted_indexes]  #predicted rating values by the new user on the movies, sorted from highest to lowest

# %% [markdown]
# **Displaying the predicted top 10 movies rated by the user**

# %%
sorted_movies = item_vecs_array[sorted_indexes]  #here we are sorting the movies based on the predicted rating values from highest to lowest
display = [["predicted_rating","movie id", "year","average_rating", "title", "genres"]]
for i in range(10):
    predicted_rating = sorted_rating_values[i]
    movie_id = sorted_movies[i,0].astype(int)  #extracting the movie_id
    year = sorted_movies[i,1]
    average_rating = sorted_movies[i,2].astype(int)  
    movie_title = movie_dict[movie_id]['title']
    movie_genre = movie_dict[movie_id]['genre']
    display.append([predicted_rating,movie_id,year,average_rating,movie_title,movie_genre])
table = tabulate.tabulate(display, tablefmt='html', headers="firstrow")
table
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  predicted_rating</th><th style="text-align: right;">  movie id</th><th style="text-align: right;">  year</th><th style="text-align: right;">  average_rating</th><th>title                                                                                         </th><th>genres                    </th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;">           4.37063</td><td style="text-align: right;">     40815</td><td style="text-align: right;">  2005</td><td style="text-align: right;">               3</td><td>Harry Potter and the Goblet of Fire (2005)                                                    </td><td>Adventure|Fantasy|Thriller</td></tr>\n<tr><td style="text-align: right;">           4.35265</td><td style="text-align: right;">    137857</td><td style="text-align: right;">  2016</td><td style="text-align: right;">               3</td><td>The Jungle Book (2016)                                                                        </td><td>Adventure|Drama|Fantasy   </td></tr>\n<tr><td style="text-align: right;">           4.32897</td><td style="text-align: right;">     59501</td><td style="text-align: right;">  2008</td><td style="text-align: right;">               3</td><td>Chronicles of Narnia: Prince Caspian, The (2008)                                              </td><td>Adventure|Children|Fantasy</td></tr>\n<tr><td style="text-align: right;">           4.31348</td><td style="text-align: right;">     41566</td><td style="text-align: right;">  2005</td><td style="text-align: right;">               3</td><td>Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)                        </td><td>Adventure|Children|Fantasy</td></tr>\n<tr><td style="text-align: right;">           4.30519</td><td style="text-align: right;">     98809</td><td style="text-align: right;">  2012</td><td style="text-align: right;">               3</td><td>Hobbit: An Unexpected Journey, The (2012)                                                     </td><td>Adventure|Fantasy         </td></tr>\n<tr><td style="text-align: right;">           4.26667</td><td style="text-align: right;">      4896</td><td style="text-align: right;">  2001</td><td style="text-align: right;">               3</td><td>Harry Potter and the Sorcerer&#x27;s Stone (a.k.a. Harry Potter and the Philosopher&#x27;s Stone) (2001)</td><td>Adventure|Children|Fantasy</td></tr>\n<tr><td style="text-align: right;">           4.22602</td><td style="text-align: right;">     54001</td><td style="text-align: right;">  2007</td><td style="text-align: right;">               3</td><td>Harry Potter and the Order of the Phoenix (2007)                                              </td><td>Adventure|Drama|Fantasy   </td></tr>\n<tr><td style="text-align: right;">           4.20554</td><td style="text-align: right;">      5816</td><td style="text-align: right;">  2002</td><td style="text-align: right;">               3</td><td>Harry Potter and the Chamber of Secrets (2002)                                                </td><td>Adventure|Fantasy         </td></tr>\n<tr><td style="text-align: right;">           4.17386</td><td style="text-align: right;">    106489</td><td style="text-align: right;">  2013</td><td style="text-align: right;">               3</td><td>Hobbit: The Desolation of Smaug, The (2013)                                                   </td><td>Adventure|Fantasy         </td></tr>\n<tr><td style="text-align: right;">           4.15931</td><td style="text-align: right;">      8368</td><td style="text-align: right;">  2004</td><td style="text-align: right;">               3</td><td>Harry Potter and the Prisoner of Azkaban (2004)                                               </td><td>Adventure|Fantasy         </td></tr>\n</tbody>\n</table>'

# %% [markdown]
# **Creating a separate item model using the trained 2 tower neural network model**

# %%
input_item = tf.keras.layers.Input(shape =(num_item_features,))   #making the input layer for neural network model 
vm = item_nn(input_item) #passing the number of item features in the item neural network
vm = tf.keras.ops.normalize(vm, axis=1)  #applying the L2 normalization
model_m = tf.keras.Model( input_item, vm)  #creating the model with the passed input and output
model_m.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape ┃ Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer_4     │ (None, 16)   │       0 │
# │ (InputLayer)      │              │         │
# ├───────────────────┼──────────────┼─────────┤
# │ sequential_1      │ (None, 32)   │  41,376 │
# │ (Sequential)      │              │         │
# ├───────────────────┼──────────────┼─────────┤
# │ normalize_2       │ (None, 32)   │       0 │
# │ (Normalize)       │              │         │
# └───────────────────┴──────────────┴─────────┘
#  Total params: 41,376 (161.62 KB)
#  Trainable params: 41,376 (161.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
scaled_item_vecs = item_scalar.transform(item_vecs_array)
vms=model_m.predict([scaled_item_vecs[:,item_index:]])  #predicting the movie vectors
# Out:
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# C:\pythonprojects\Machine learning\unsupervised_learning\content_based_recommendation\venv\lib\site-packages\keras\src\models\functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_15
# Received: inputs=('Tensor(shape=(32, 16))',)
#   warnings.warn(msg)
# C:\pythonprojects\Machine learning\unsupervised_learning\content_based_recommendation\venv\lib\site-packages\keras\src\models\functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_15
# Received: inputs=('Tensor(shape=(None, 16))',)
#   warnings.warn(msg)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
vms
# Out:
# array([[-0.0582903 , -0.04935281, -0.15199116, ..., -0.20586327,
#          0.2344707 , -0.17343727],
#        [-0.12352227, -0.07315271, -0.29815856, ..., -0.18947133,
#          0.24822639, -0.11345572],
#        [-0.05262928,  0.06050648, -0.06569456, ..., -0.29354477,
#          0.02712594,  0.00487133],
#        ...,
#        [-0.3001253 , -0.23586261, -0.06230097, ...,  0.22475092,
#         -0.05331366,  0.0718838 ],
#        [-0.18818398, -0.08859497, -0.3090672 , ...,  0.32311937,
#          0.0646043 , -0.15577655],
#        [-0.00145776, -0.24307843, -0.229867  , ...,  0.03074262,
#         -0.02581507,  0.10288768]], shape=(847, 32), dtype=float32)

# %% [markdown]
# **Square distance between two vectors**

# %%
def square_distance(a,b):
    return np.sum(np.square(a-b))
a1 = np.array([1.0, 2.0, 3.0]); b1 = np.array([1.0, 2.0, 3.0])
a2 = np.array([1.1, 2.1, 3.1]); b2 = np.array([1.0, 2.0, 3.0])
a3 = np.array([0, 1, 0]);       b3 = np.array([1, 0, 0])
print(f"squared distance between a1 and b1: {square_distance(a1, b1):0.3f}")
print(f"squared distance between a2 and b2: {square_distance(a2, b2):0.3f}")
print(f"squared distance between a3 and b3: {square_distance(a3, b3):0.3f}")
# Out:
# squared distance between a1 and b1: 0.000
# squared distance between a2 and b2: 0.030
# squared distance between a3 and b3: 2.000
